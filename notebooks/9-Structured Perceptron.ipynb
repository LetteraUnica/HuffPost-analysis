# %%
from collections import defaultdict, Counter
import json
import re
import numpy as np
import sys
import pickle
import random

np.set_printoptions(precision=2)

users = re.compile('@[^ ]+')
numbers = re.compile('[0-9]')
urls = re.compile("(https?:\/\/)?(?:www\.|(?!www))?[^\s\.]+\.[^\s]{2,}|(www)?\.[^\s]+\.[^\s]{2,}")

# %%
class StructuredPerceptron(object):
    """
    implements a structured perceptron as described in Collins 2002,
    with updates from https://explosion.ai/blog/part-of-speech-pos-tagger-in-python
    """

    def __init__(self):
        """
        initialize model parameters
        """
        self.tags = set()
        self.feature_weights = defaultdict(lambda: defaultdict(float)) #feature_name -> tags -> weight
        self.weight_totals = defaultdict(lambda: defaultdict(float)) #feature_name -> tags -> weight
        self.timestamps = defaultdict(lambda: defaultdict(float)) #feature_name -> tags -> weight

        self.tag_dict = defaultdict(set) #word -> {tags}

        self.START = "__START__"
        self.END = "__END__"

        self.Q = None
        self.backpointers = None

        # self.instances = None
        
        
    def normalize(self, word):
        """
        lowercase word, and replace numbers, user names, and URLs
        """
        return re.sub(urls, 'URL', re.sub(users, '@USER', re.sub(numbers, '0', word.strip().lower())))

    
    def evaluate(self, data_instances, method='greedy'):
        correct = 0
        total = 0
        for (words, tags) in data_instances:
            preds = self.predict(words, method=method)
            matches = sum(map(lambda x: int(x[0]==x[1]), zip(preds, tags)))
            correct += matches
            total += len(tags)
        return correct/total
        
    
    def fit(self, file_name, dev_file=None, iterations=10, learning_rate=0.25, inference='greedy', verbose=False):
        """
        read in a CoNLL-format file, extract features to train weight vector
        """        
        # initialize tag dictionary for each word and get tag set
        self.instances = [(words, tags) for (words, tags) in self.read_conll_file(file_name)]
        instances = self.instances
        for (words, tags) in instances:
            self.tags.update(set(tags))

            for word, tag in zip(words, tags):
                self.tag_dict[self.normalize(word)].add(tag)
        
        if dev_file:
            dev_instances = [(words, tags) for (words, tags) in self.read_conll_file(dev_file)]
            
        # iterate over data
        for iteration in range(1, iterations+1):
            correct = 0
            total = 0
            if verbose:
                print('Iteration {}'.format(iteration+1), file=sys.stderr, flush=True)
                print("*" * 15, file=sys.stderr, flush=True)

            random.shuffle(instances)
            for i, (words, tags) in enumerate(instances):
                if i > 0:
                    if i%1000==0:
                        print('%s'%i, file=sys.stderr, flush=True)
                    elif i%20==0:
                        print('.', file=sys.stderr, flush=True, end='')

                # get prediction
                prediction = self.predict(words, method=inference)

                # derive global features
                global_gold_features, global_prediction_features = self.get_global_features(words, prediction, tags)
                                    
                # update weight vector:
                # 1. move closer to true tag
                for tag, fids in global_gold_features.items():
                    for fid, count in fids.items():
                        nr_iters_at_this_weight = iteration - self.timestamps[fid][tag]
                        self.weight_totals[fid][tag] += nr_iters_at_this_weight * self.feature_weights[fid][tag]
                        self.timestamps[fid][tag] = iteration
                        self.feature_weights[fid][tag] += learning_rate * count

                # 2. move further from wrong tag
                for tag, fids in global_prediction_features.items():
                    for fid, count in fids.items():
                        nr_iters_at_this_weight = iteration - self.timestamps[fid][tag]
                        self.weight_totals[fid][tag] += nr_iters_at_this_weight * self.feature_weights[fid][tag]
                        self.timestamps[fid][tag] = iteration
                        self.feature_weights[fid][tag] -= learning_rate * count
                        
                # compute training accuracy for this iteration
                correct += sum([int(predicted_tag == true_tag) for predicted_tag, true_tag in zip(prediction, tags)])
                total += len(tags)

                # output examples
                if verbose and i%1000==0:
                    print("current word accuracy:{:.2f}".format(correct/total))
                    print(list(zip(words, 
                                   [self.normalize(word) for word in words], 
                                   tags, 
                                   prediction)), file=sys.stderr, flush=True)
            
            print('\t{} features'.format(len(self.feature_weights)), file=sys.stderr, flush=True)
            print('\tTraining accuracy: {:.2f}\n'.format(correct/total), file=sys.stderr, flush=True)
            if dev_file:
                print('\tDevelopment accuracy: {:.2f}\n'.format(self.evaluate(dev_instances, method=inference)), file=sys.stderr, flush=True)
         
        # average weights
        for feature, tags in self.feature_weights.items():
            for tag in tags:
                total = self.weight_totals[feature][tag]
                total += (iterations - self.timestamps[feature][tag]) * self.feature_weights[feature][tag]
                averaged = round(total / float(iterations), 3)
                self.feature_weights[feature][tag] = averaged


    def get_features(self, word, previous_tag2, previous_tag, words, i):
        """
        get all features that can be derived from the word and previous tags
        """
        prefix = word[:3]
        suffix = word[-3:]

        features = {
                    'PREFIX={}'.format(prefix),
                    'SUFFIX={}'.format(suffix),
                    'LEN<=3={}'.format(len(word)<=3),
                    'FIRST_LETTER={}'.format(word[0]),
                    'WORD={}'.format(word),
                    'NORM_WORD={}'.format(words[i]),
                    'PREV_WORD={}'.format(words[i-1]),
                    'PREV_WORD_PREFIX={}'.format(words[i-1][:3]),
                    'PREV_WORD_SUFFIX={}'.format(words[i-1][-3:]),
                    'PREV_WORD+WORD={}+{}'.format(words[i-1], words[i]),
                    'NEXT_WORD={}'.format(words[i+1]),
                    'NEXT_WORD_PREFIX={}'.format(words[i+1][:3]),
                    'NEXT_WORD_SUFFIX={}'.format(words[i+1][-3:]),
                    'WORD+NEXT_WORD={}'.format(word, words[i+1]),
                    'NEXT_2WORDS={}+{}'.format(words[i+1], words[i+2]),
                    'PREV_TAG={}'.format(previous_tag),                 # previous tag
                    'PREV_TAG2={}'.format(previous_tag2),                 # two-previous tag
                    'PREV_TAG_BIGRAM={}+{}'.format(previous_tag2, previous_tag),  # tag bigram
                    'PREV_TAG+WORD={}+{}'.format(previous_tag, word),            # word-tag combination
                    'PREV_TAG+PREFIX={}_{}'.format(previous_tag, prefix),        # prefix and tag
                    'PREV_TAG+SUFFIX={}_{}'.format(previous_tag, suffix),        # suffix and tag
                    'WORD+TAG_BIGRAM={}+{}+{}'.format(word, previous_tag2, previous_tag),
                    'SUFFIX+2TAGS={}+{}+{}'.format(suffix, previous_tag2, previous_tag),
                    'PREFIX+2TAGS={}+{}+{}'.format(prefix, previous_tag2, previous_tag),
                    'BIAS'
            }
        return features
    
    
    def get_global_features(self, words, predicted_tags, true_tags):
        '''
        sum up local features
        '''
        context = [self.START] + [self.normalize(word) for word in words] + [self.END, self.END]

        global_gold_features = defaultdict(lambda: Counter())
        global_prediction_features = defaultdict(lambda: Counter())

        prev_predicted_tag = self.START
        prev_predicted_tag2 = self.START
        
        for j, (word, predicted_tag, true_tag) in enumerate(zip(words, predicted_tags, true_tags)):
            # get the predicted features. NB: use j+1, since context is longer than words
            prediction_features = self.get_features(word, prev_predicted_tag2, prev_predicted_tag, context, j+1)

            # update feature correlation with true and predicted tag
            global_prediction_features[predicted_tag].update(prediction_features)
            global_gold_features[true_tag].update(prediction_features)

            prev_predicted_tag2 = prev_predicted_tag
            prev_predicted_tag = predicted_tag

        return global_gold_features, global_prediction_features
            
    
    def get_scores(self, features):
        """
        predict scores for each tag given features
        """
        scores = defaultdict(float)
        
        # add up the scores for each tag
        for feature in features:
            if feature not in self.feature_weights:
                continue
            weights = self.feature_weights[feature]
            for tag, weight in weights.items():
                scores[tag] += weight

        # return tag scores
        if not scores:
            # if there are no scores (e.g., first iteration),
            # simply return the first tag with score 1
            scores[list(self.tags)[0]] = 1
        
        return scores


    def predict(self, words, method='greedy'):
        '''
        predict tags using one of two methods
        '''
        if method == 'greedy':
            return self.predict_greedy(words)
        elif method == 'viterbi':
            return self.predict_viterbi(words)


    def predict_viterbi(self, words):
        '''
        predict using Viterbi decoding
        '''
        context = [self.START] + [self.normalize(word) for word in words] + [self.END, self.END]

        N = len(words)
        M = len(self.tags) #number of tags
        tags = sorted(self.tags)

        # create trellis of size M (number of tags) x N (sentence length)
        self.Q = np.ones((M, N)) * float('-Inf')
        self.backpointers = np.ones((M, N), dtype=np.int16) * -1 #backpointers

        # initialize probs for tags j at position 1 (first word)
        features = self.get_features(words[0], self.START, self.START, context, 1)
        scores = self.get_scores(features)
        allowed_initial_tags = self.tag_dict[context[1]]

        for j in range(M):
            if not allowed_initial_tags or tags[j] in allowed_initial_tags:
                Q[j,0] = scores[tags[j]]

        # filling the lattice, for every position and every tag find viterbi score Q
        for i in range(1, N):
            allowed_tags = self.tag_dict[context[i+1]]

            # for every previous tag
            for j in range(M):
                best_score = 0.0 #float('-Inf')
                prev_tag = tags[j]

                # skip impossible tags
                allowed_previous_tags = self.tag_dict[context[i]]
                if allowed_previous_tags and prev_tag not in allowed_previous_tags:
                    continue

                best_before = self.Q[j,i-1] # score of previous tag

                # for every possible pre-previous tag
                for k in range(M):
                    if i == 1:
                        prev2_tag = self.START
                    else:
                        prev2_tag = tags[k]
                        # skip impossible tags
                        allowed_previous2_tags = self.tag_dict[context[i-1]]
                        if allowed_previous2_tags and prev2_tag not in allowed_previous2_tags:
                            continue

                    # get features of word i with the two previous tags
                    features = self.get_features(words[i], prev2_tag, prev_tag, context, i+1)
                    scores = self.get_scores(features)

                    # update best score
                    for t in range(M):
                        tag = tags[t]
                        # if word is unknown, use all tags, otherwise allowed ones
                        if not allowed_tags or tag in allowed_tags:
                            tag_score = best_before + scores[tag]

                            if tag_score > best_score:
                                self.Q[t,i] = tag_score
                                best_score = tag_score
                                self.backpointers[t,i] = j

        # final best
        best_id = self.Q[:,-1].argmax()

        # print best tags in reverse order
        predtags = [tags[best_id]]

        for i in range(N-1,0,-1):
            idx = self.backpointers[best_id, i]
            predtags.append(tags[idx])
            best_id = idx

        #return reversed predtags
        return predtags[::-1]         

    
    def predict_greedy(self, words):
        '''
        greedy prediction
        '''
        context = [self.START] + [self.normalize(word) for word in words] + [self.END, self.END]
                
        prev_predicted_tag = self.START
        prev_predicted_tag2 = self.START

        out = []

        for j, word in enumerate(words):
            # for unambiguous words, just look up the tag
            predicted_tag = list(self.tag_dict[context[j+1]])[0] if len(self.tag_dict[context[j+1]]) == 1 else None

            if not predicted_tag:
                # get the predicted features. NB: use j+1, since context is longer than words
                prediction_features = self.get_features(word, prev_predicted_tag2, prev_predicted_tag, context, j+1)
                scores = self.get_scores(prediction_features)
                
                # predict the current tag
                predicted_tag = max(scores, key=scores.get)

            prev_predicted_tag2 = prev_predicted_tag
            prev_predicted_tag = predicted_tag

            out.append(predicted_tag)

        return out
    
        
    def read_conll_file(self, file_name):
        """
        read in a file with CoNLL format:
        word1    tag1
        word2    tag2
        ...      ...
        wordN    tagN

        Sentences MUST be separated by newlines!
        """
        current_words = []
        current_tags = []

        with open(file_name, encoding='utf-8') as conll:
            for line in conll:
                line = line.strip()

                if line:
                    word, tag = line.split('\t')
                    current_words.append(word)
                    current_tags.append(tag)

                else:
                    yield (current_words, current_tags)
                    current_words = []
                    current_tags = []

        # if file does not end in newline (it should...), check whether there is an instance in the buffer
        if current_tags != []:
            yield (current_words, current_tags)
        

    def save(self, file_name):
        """
        save model as pickle file
        """
        print("saving model...", end=' ', file=sys.stderr)
        with open(file_name, "wb") as model:
            # pickle cannot save default_dictionaries
            # => make copy and turn into regular dictionaries
            save_feature_weights = defaultdict(lambda: defaultdict(float))
            save_feature_weights.update(self.feature_weights)
            save_tag_dict = defaultdict(set)
            save_tag_dict.update(self.tag_dict)

            save_feature_weights.default_factory = None
            save_tag_dict.default_factory = None
            pickle.dump((save_feature_weights, save_tag_dict, self.tags),
                     model, -1)
        print("done", file=sys.stderr)


    def load(self, file_name):
        """
        load model from pickle file
        """
        print("loading model...", end=' ', file=sys.stderr)
        with open(file_name, 'rb') as model:
            try:
                parameters = pickle.load(model)
            except IOError:
                msg = ("No such model file.")
                raise MissingCorpusError(msg)

            feature_weights, tag_dict, tags = parameters
            self.tags = tags

            # pickle cannot store defaultdicts, so we need a 2-step process
            # 1. initialize
            self.feature_weights = defaultdict(lambda: defaultdict(float))
            self.tag_dict = defaultdict(set)
            
            # 2. update
            self.feature_weights.update(feature_weights)
            self.tag_dict.update(tag_dict)
        print("done", file=sys.stderr)
        return None

# %%
sp = StructuredPerceptron()
inference_method = 'greedy'
# %time sp.fit('tiny_POS_train.data', dev_file='tiny_POS_test.data', iterations=10, inference=inference_method)
sp.save('model_greedy.pickle')
# Out:
# .................................................1000
# .................................................2000
# 	181847 features
# 	Training accuracy: 0.95
#
# 	Development accuracy: 0.91
#
# .................................................1000
# .................................................2000
# 	187490 features
# 	Training accuracy: 0.98
#
# 	Development accuracy: 0.91
#
# .................................................1000
# .................................................2000
# 	189026 features
# 	Training accuracy: 0.99
#
# 	Development accuracy: 0.92
#
# .................................................1000
# .................................................2000
# 	189671 features
# 	Training accuracy: 0.99
#
# 	Development accuracy: 0.92
#
# .................................................1000
# .................................................2000
# 	190056 features
# 	Training accuracy: 0.99
#
# 	Development accuracy: 0.92
#
# .................................................1000
# .................................................2000
# 	190221 features
# 	Training accuracy: 1.00
#
# 	Development accuracy: 0.93
#
# .................................................1000
# .................................................2000
# 	190388 features
# 	Training accuracy: 1.00
#
# 	Development accuracy: 0.92
#
# .................................................1000
# .................................................2000
# 	190560 features
# 	Training accuracy: 1.00
#
# 	Development accuracy: 0.92
#
# .................................................1000
# .................................................2000
# 	190692 features
# 	Training accuracy: 1.00
#
# 	Development accuracy: 0.92
#
# .................................................1000
# .................................................2000
# 	190760 features
# 	Training accuracy: 1.00
#
# 	Development accuracy: 0.92
# CPU times: user 1min 33s, sys: 757 ms, total: 1min 34s
# Wall time: 1min 35s
# saving model... done

# %% [markdown]
# ## DEBUG GREEDY

# %%
sp.tags
# Out:
# {'.',
#  'ADJ',
#  'ADP',
#  'ADV',
#  'CONJ',
#  'DET',
#  'NOUN',
#  'NUM',
#  'PRON',
#  'PRT',
#  'VERB',
#  'X'}

# %%
sp.tag_dict
# Out:
# defaultdict(set,
#             {'showtime': {'NOUN'},
#              'is': {'VERB'},
#              'a': {'DET', 'NOUN'},
#              'distant': {'ADJ'},
#              'no.': {'NOUN'},
#              '0': {'NUM'},
#              'to': {'ADP', 'PRT'},
#              'home': {'NOUN'},
#              'box': {'NOUN'},
#              'office': {'NOUN'},
#              ',': {'.'},
#              'and': {'CONJ'},
#              'in': {'ADP', 'ADV', 'PRT'},
#              'may': {'NOUN', 'VERB'},
#              'filed': {'VERB'},
#              '$': {'.'},
#              '0.0': {'NUM'},
#              'billion': {'NUM'},
#              'antitrust': {'ADJ'},
#              'suit': {'ADV', 'NOUN'},
#              'against': {'ADP'},
#              'time': {'NOUN'},
#              'warner': {'NOUN'},
#              'charging': {'VERB'},
#              'the': {'DET', 'NOUN'},
#              'company': {'NOUN'},
#              'its': {'PRON'},
#              'hbo': {'NOUN'},
#              'american': {'ADJ', 'NOUN'},
#              'television': {'NOUN'},
#              'cable': {'NOUN'},
#              'units': {'NOUN'},
#              'with': {'ADP'},
#              'conspiring': {'VERB'},
#              'monopolize': {'VERB'},
#              'pay': {'NOUN', 'VERB'},
#              'tv': {'NOUN'},
#              'business': {'NOUN'},
#              '.': {'.'},
#              'has': {'VERB'},
#              'close': {'ADJ', 'ADV', 'NOUN', 'VERB'},
#              '00': {'NUM'},
#              'million': {'NUM'},
#              'subscribers': {'NOUN'},
#              'cinemax': {'NOUN'},
#              'networks': {'NOUN'},
#              'while': {'ADP', 'NOUN'},
#              'sister': {'NOUN'},
#              'service': {'NOUN'},
#              'movie': {'NOUN'},
#              'channel': {'NOUN'},
#              'have': {'VERB'},
#              'only': {'ADJ', 'ADV'},
#              'about': {'ADP'},
#              'according': {'VERB'},
#              'paul': {'NOUN'},
#              'kagan': {'NOUN'},
#              'associates': {'NOUN'},
#              'carmel': {'NOUN'},
#              'calif.': {'NOUN'},
#              'research': {'NOUN'},
#              'firm': {'ADJ', 'NOUN'},
#              'for': {'ADP'},
#              'tci': {'NOUN'},
#              'investment': {'NOUN'},
#              'puts': {'VERB'},
#              'it': {'PRON'},
#              'an': {'DET'},
#              'unusual': {'ADJ'},
#              'position': {'NOUN'},
#              ';': {'.'},
#              'as': {'ADP', 'ADV'},
#              'largest': {'ADJ'},
#              'operator': {'NOUN'},
#              'control': {'NOUN'},
#              'of': {'ADP'},
#              'nation': {'NOUN'},
#              "'s": {'PRON', 'PRT', 'VERB'},
#              'customer': {'NOUN'},
#              'but': {'CONJ'},
#              'president': {'NOUN'},
#              'john': {'NOUN'},
#              'malone': {'NOUN'},
#              'long': {'ADJ', 'ADV'},
#              'been': {'VERB'},
#              'concerned': {'ADJ', 'VERB'},
#              'dominance': {'NOUN'},
#              'eager': {'ADJ'},
#              'keep': {'VERB'},
#              'healthy': {'ADJ'},
#              'competitor': {'NOUN'},
#              '``': {'.'},
#              'important': {'ADJ'},
#              'industry': {'NOUN'},
#              'that': {'ADP', 'ADV', 'DET'},
#              'we': {'PRON'},
#              'vibrant': {'ADJ'},
#              'competitive': {'ADJ'},
#              'pay-television': {'NOUN'},
#              'marketplace': {'NOUN'},
#              "''": {'.'},
#              'mr.': {'NOUN'},
#              'said': {'VERB'},
#              'statement': {'NOUN'},
#              'telephone': {'NOUN'},
#              'interview': {'NOUN'},
#              'robert': {'NOUN'},
#              'thomson': {'NOUN'},
#              'senior': {'ADJ'},
#              'vice': {'NOUN'},
#              'does': {'VERB'},
#              "n't": {'ADV'},
#              'involve': {'VERB'},
#              'us': {'PRON'},
#              'nothing': {'NOUN'},
#              "'re": {'VERB'},
#              'doing': {'VERB'},
#              'here': {'ADV'},
#              'bears': {'VERB'},
#              'any': {'DET'},
#              'relationship': {'NOUN'},
#              'he': {'PRON'},
#              'added': {'VERB'},
#              'do': {'VERB'},
#              'intend': {'VERB'},
#              'be': {'VERB'},
#              'drawn': {'VERB'},
#              'into': {'ADP'},
#              'noting': {'VERB'},
#              'wo': {'VERB'},
#              'play': {'NOUN', 'VERB'},
#              'active': {'ADJ'},
#              'role': {'NOUN'},
#              'management': {'NOUN'},
#              'linking': {'VERB'},
#              'up': {'ADP', 'ADV', 'PRT'},
#              'URL': {'ADV', 'NOUN', 'NUM'},
#              'could': {'VERB'},
#              'sharply': {'ADV'},
#              'boost': {'NOUN', 'VERB'},
#              'bring': {'VERB'},
#              'other': {'ADJ'},
#              'operators': {'NOUN'},
#              'investors': {'NOUN'},
#              'practice': {'NOUN'},
#              'employed': {'VERB'},
#              'past': {'ADJ', 'ADV', 'NOUN'},
#              'investments': {'NOUN'},
#              'such': {'ADJ', 'DET'},
#              'discovery': {'NOUN'},
#              'additional': {'ADJ'},
#              'partners': {'NOUN'},
#              'even': {'ADJ', 'ADV'},
#              'further': {'ADJ', 'ADV'},
#              'declined': {'VERB'},
#              'comment': {'NOUN', 'VERB'},
#              'addition': {'NOUN'},
#              'owning': {'VERB'},
#              'owns': {'VERB'},
#              '&': {'CONJ'},
#              'communications': {'NOUN'},
#              'inc.': {'NOUN'},
#              'second': {'ADJ'},
#              'after': {'ADP'},
#              'viacom': {'NOUN'},
#              'also': {'ADV'},
#              'systems': {'NOUN'},
#              '00th': {'ADJ'},
#              'less': {'ADJ', 'ADV', 'NOUN'},
#              'than': {'ADP'},
#              'one': {'NOUN', 'NUM', 'PRON'},
#              'big': {'ADJ', 'NOUN'},
#              'victory': {'NOUN'},
#              'chief': {'ADJ', 'NOUN'},
#              'executive': {'ADJ', 'NOUN'},
#              'officer': {'NOUN'},
#              'frank': {'NOUN'},
#              'biondi': {'NOUN'},
#              'winston': {'NOUN'},
#              'h.': {'NOUN'},
#              'cox': {'NOUN'},
#              'unit': {'NOUN'},
#              'this': {'DET'},
#              'takes': {'VERB'},
#              'question': {'NOUN', 'VERB'},
#              'viability': {'NOUN'},
#              'away': {'ADV', 'PRT'},
#              'once': {'ADP', 'ADV'},
#              'all': {'ADV', 'DET'},
#              'fight': {'NOUN', 'VERB'},
#              'between': {'ADP'},
#              'particularly': {'ADV'},
#              'acrimonious': {'ADJ'},
#              'because': {'ADP', 'ADV'},
#              'former': {'ADJ'},
#              'served': {'VERB'},
#              'marketing': {'NOUN'},
#              'they': {'PRON'},
#              'were': {'VERB'},
#              'both': {'DET'},
#              'hired': {'VERB'},
#              'by': {'ADP'},
#              'sumner': {'NOUN'},
#              'redstone': {'NOUN'},
#              'boston': {'NOUN'},
#              'billionaire': {'NOUN'},
#              'who': {'PRON'},
#              'took': {'VERB'},
#              'three': {'NOUN', 'NUM'},
#              'years': {'NOUN'},
#              'ago': {'ADP', 'ADV'},
#              'leveraged': {'ADJ'},
#              'buy-out': {'NOUN'},
#              'vigorously': {'ADV'},
#              'denied': {'VERB'},
#              'allegations': {'NOUN'},
#              'boeing': {'NOUN'},
#              'co.': {'NOUN'},
#              'already': {'ADV'},
#              'struck': {'VERB'},
#              'machinists': {'NOUN'},
#              'union': {'NOUN'},
#              'briefly': {'NOUN'},
#              'called': {'VERB'},
#              'off': {'ADP', 'ADV', 'PRT'},
#              'contract': {'NOUN'},
#              'talks': {'NOUN', 'VERB'},
#              'engineers': {'NOUN'},
#              'labeled': {'VERB'},
#              'their': {'PRON'},
#              'demands': {'NOUN'},
#              'grossly': {'ADV'},
#              'excessive': {'ADJ'},
#              'later': {'ADV'},
#              'however': {'ADV'},
#              'agreed': {'VERB'},
#              'meet': {'VERB'},
#              'on': {'ADP', 'ADV', 'NOUN', 'PRT'},
#              'monday': {'NOUN'},
#              'seattle': {'NOUN'},
#              'professional': {'ADJ', 'NOUN'},
#              'engineering': {'NOUN'},
#              'employees': {'NOUN'},
#              'association': {'NOUN'},
#              'federal': {'ADJ', 'NOUN'},
#              'mediator': {'NOUN'},
#              'intervened': {'VERB'},
#              'spokesman': {'NOUN'},
#              'asked': {'VERB'},
#              'reduce': {'VERB'},
#              'which': {'DET'},
#              'included': {'VERB'},
#              '%': {'NOUN'},
#              'hike': {'NOUN'},
#              'first': {'ADJ', 'ADV', 'NOUN'},
#              'year': {'NOUN'},
#              'third': {'ADJ', 'NOUN'},
#              'represents': {'VERB'},
#              '00,000': {'NUM'},
#              'technical': {'ADJ'},
#              'workers': {'NOUN'},
#              'expires': {'VERB'},
#              'dec.': {'NOUN'},
#              'meanwhile': {'ADV'},
#              'scheduled': {'ADJ', 'VERB'},
#              'today': {'NOUN'},
#              'officials': {'NOUN'},
#              'representatives': {'NOUN'},
#              'striking': {'ADJ'},
#              'will': {'NOUN', 'VERB'},
#              'take': {'VERB'},
#              'several': {'ADJ'},
#              'meetings': {'NOUN'},
#              'resolve': {'VERB'},
#              'want': {'VERB'},
#              'back': {'ADJ', 'ADV', 'NOUN', 'PRT', 'VERB'},
#              'something': {'NOUN'},
#              'members': {'NOUN'},
#              'reject': {'VERB'},
#              'rejected': {'VERB'},
#              'package': {'NOUN', 'VERB'},
#              'would': {'VERB'},
#              'provided': {'VERB'},
#              'raise': {'NOUN', 'VERB'},
#              'plus': {'CONJ', 'NOUN'},
#              'bonuses': {'NOUN'},
#              'over': {'ADP', 'ADV', 'PRT'},
#              'three-year': {'ADJ'},
#              'life': {'NOUN'},
#              'reduced': {'VERB'},
#              'mandatory': {'ADJ'},
#              'overtime': {'NOUN'},
#              'investor': {'NOUN'},
#              'asher': {'NOUN'},
#              'edelman': {'NOUN'},
#              'increased': {'VERB'},
#              'his': {'PRON'},
#              'stake': {'NOUN'},
#              'intelogic': {'NOUN'},
#              'trace': {'NOUN'},
#              'cleared': {'VERB'},
#              'way': {'NOUN'},
#              'purchases': {'NOUN'},
#              'was': {'VERB'},
#              'clear': {'ADJ'},
#              'whether': {'ADP'},
#              'actions': {'NOUN'},
#              'related': {'ADJ', 'VERB'},
#              'battle': {'NOUN'},
#              'corporate': {'ADJ'},
#              'raider': {'NOUN'},
#              'new': {'ADJ', 'NOUN'},
#              'york': {'NOUN'},
#              'attorney': {'NOUN'},
#              'martin': {'NOUN'},
#              'ackerman': {'NOUN'},
#              'datapoint': {'NOUN'},
#              'corp.': {'NOUN'},
#              'san': {'NOUN'},
#              'antonio': {'NOUN'},
#              'texas-based': {'ADJ'},
#              'data-processing': {'NOUN'},
#              'maker': {'NOUN'},
#              'computer': {'NOUN'},
#              'services': {'NOUN'},
#              'spun': {'VERB'},
#              'holders': {'NOUN'},
#              '0000': {'NUM'},
#              'gained': {'VERB'},
#              'announced': {'ADJ', 'VERB'},
#              'soliciting': {'VERB'},
#              'consents': {'NOUN'},
#              'from': {'ADP'},
#              'shareholders': {'NOUN'},
#              'order': {'NOUN', 'VERB'},
#              'wrest': {'VERB'},
#              'purchased': {'VERB'},
#              'shares': {'NOUN'},
#              'securities': {'NOUN'},
#              'exchange': {'NOUN'},
#              'commission': {'NOUN'},
#              'filing': {'NOUN'},
#              'sept.': {'NOUN'},
#              'oct.': {'NOUN'},
#              'acquired': {'VERB'},
#              '000,000': {'NUM'},
#              'common': {'ADJ'},
#              'each': {'DET'},
#              '00.0': {'NUM'},
#              'outstanding': {'ADJ'},
#              'certain': {'ADJ'},
#              'provisions': {'NOUN'},
#              'apply': {'VERB'},
#              'persons': {'NOUN'},
#              'acquiring': {'VERB'},
#              'or': {'CONJ'},
#              'more': {'ADJ', 'ADV'},
#              'stock': {'NOUN', 'VERB'},
#              'waived': {'VERB'},
#              'chairman': {'NOUN'},
#              'reached': {'VERB'},
#              'government': {'NOUN'},
#              'should': {'NOUN', 'VERB'},
#              'make': {'VERB'},
#              'free': {'ADJ', 'ADV'},
#              'voluntary': {'ADJ'},
#              'testing': {'NOUN', 'VERB'},
#              'aids': {'NOUN'},
#              'virus': {'NOUN'},
#              'cornerstone': {'NOUN'},
#              'expanded': {'VERB'},
#              'campaign': {'NOUN'},
#              'stop': {'NOUN', 'VERB'},
#              'spread': {'NOUN', 'VERB'},
#              'immune': {'ADJ'},
#              'deficiency': {'NOUN'},
#              'syndrome': {'NOUN'},
#              'hudson': {'NOUN'},
#              'institute': {'NOUN'},
#              'recommended': {'VERB'},
#              'encouraging': {'ADJ', 'VERB'},
#              'massive': {'ADJ'},
#              'routine': {'ADJ'},
#              'can': {'VERB'},
#              'enable': {'VERB'},
#              'society': {'NOUN'},
#              'voluntarily': {'ADV'},
#              'segregate': {'VERB'},
#              'itself': {'PRON'},
#              'sexually': {'ADV'},
#              'two': {'NUM'},
#              'groups': {'NOUN'},
#              ':': {'.'},
#              'those': {'DET'},
#              'carry': {'VERB'},
#              'not': {'ADV'},
#              'indianapolis': {'NOUN'},
#              'organization': {'NOUN'},
#              'report': {'NOUN', 'VERB'},
#              'alarmed': {'ADJ'},
#              'view': {'NOUN', 'VERB'},
#              'recommends': {'VERB'},
#              'sweeping': {'ADJ'},
#              'response': {'NOUN'},
#              'many': {'ADJ', 'DET'},
#              'analyses': {'NOUN'},
#              'warns': {'VERB'},
#              'epidemic': {'NOUN'},
#              'rate': {'NOUN'},
#              'growth': {'ADJ', 'NOUN'},
#              'work': {'NOUN', 'VERB'},
#              'force': {'NOUN', 'VERB'},
#              'curb': {'VERB'},
#              'productivity': {'NOUN'},
#              'gains': {'NOUN'},
#              'slow': {'ADJ', 'VERB'},
#              'economic': {'ADJ', 'NOUN'},
#              'contends': {'VERB'},
#              'current': {'ADJ'},
#              'policy': {'NOUN'},
#              'failing': {'VERB'},
#              'stem': {'VERB'},
#              'suggests': {'VERB'},
#              'use': {'NOUN', 'VERB'},
#              'condoms': {'NOUN'},
#              'sex': {'NOUN'},
#              'safe': {'ADJ'},
#              'says': {'VERB'},
#              'uninfected': {'ADJ'},
#              'learn': {'VERB'},
#              'infection': {'NOUN'},
#              'researchers': {'NOUN'},
#              'estimated': {'VERB'},
#              'cost': {'NOUN', 'VERB'},
#              '000': {'NUM'},
#              'test': {'NOUN', 'VERB'},
#              'entire': {'ADJ'},
#              'population': {'NOUN'},
#              'ages': {'NOUN'},
#              'old': {'ADJ'},
#              'state': {'NOUN'},
#              'governments': {'NOUN'},
#              'provide': {'VERB'},
#              'treatment': {'NOUN'},
#              'positive': {'ADJ'},
#              'unexpectedly': {'ADV'},
#              'sharp': {'ADJ'},
#              'widening': {'NOUN'},
#              'trade': {'NOUN', 'VERB'},
#              'gap': {'NOUN'},
#              'august': {'NOUN'},
#              'dragged': {'VERB'},
#              'dollar': {'NOUN'},
#              'lower': {'ADJ', 'ADV'},
#              'tuesday': {'NOUN'},
#              'profit-taking': {'NOUN'},
#              'short': {'ADJ', 'ADV'},
#              'positions': {'NOUN'},
#              'helped': {'VERB'},
#              'currency': {'NOUN'},
#              'rebound': {'NOUN'},
#              'mixed': {'VERB'},
#              'major': {'ADJ'},
#              'counterparts': {'NOUN'},
#              'market': {'NOUN', 'VERB'},
#              'kept': {'VERB'},
#              'careful': {'ADJ'},
#              'tabs': {'NOUN'},
#              'wall': {'NOUN'},
#              'street': {'NOUN'},
#              'gyrations': {'NOUN'},
#              'shrugged': {'VERB'},
#              'modest': {'ADJ'},
#              'downturn': {'NOUN'},
#              'equities': {'NOUN'},
#              'bid': {'NOUN', 'VERB'},
#              'well': {'ADJ', 'ADV'},
#              'above': {'ADP'},
#              'day': {'NOUN'},
#              'lows': {'NOUN'},
#              'soon': {'ADV'},
#              'release': {'NOUN'},
#              'figures': {'NOUN'},
#              'plunged': {'VERB'},
#              'intraday': {'ADJ', 'NOUN'},
#              'low': {'ADJ', 'ADV'},
#              'yen': {'NOUN'},
#              'mark': {'NOUN', 'VERB'},
#              'did': {'VERB'},
#              'reach': {'NOUN', 'VERB'},
#              'marks': {'NOUN'},
#              'until': {'ADP'},
#              'hours': {'NOUN'},
#              'stabilized': {'VERB'},
#              'midday': {'NOUN'},
#              'at': {'ADP'},
#              'around': {'ADP', 'ADV', 'PRT'},
#              'prompting': {'VERB'},
#              'unconfirmed': {'ADJ'},
#              'rumors': {'NOUN'},
#              'reserve': {'ADJ', 'NOUN'},
#              'had': {'VERB'},
#              'blunt': {'ADJ', 'NOUN', 'VERB'},
#              'tumble': {'NOUN'},
#              'finished': {'VERB'},
#              'highs': {'NOUN'},
#              'dealers': {'NOUN'},
#              'noted': {'VERB'},
#              'foreign': {'ADJ'},
#              'initial': {'ADJ'},
#              'bearish': {'ADJ'},
#              'reaction': {'NOUN'},
#              'tempered': {'VERB'},
#              'calmer': {'ADJ'},
#              'reassessment': {'NOUN'},
#              'data': {'NOUN'},
#              'commerce': {'NOUN'},
#              'department': {'NOUN'},
#              'reported': {'VERB'},
#              'deficit': {'NOUN'},
#              'compared': {'VERB'},
#              'revised': {'ADJ', 'VERB'},
#              'july': {'NOUN'},
#              'economists': {'NOUN'},
#              'expected': {'ADJ', 'VERB'},
#              'figure': {'NOUN', 'VERB'},
#              'reflected': {'VERB'},
#              'rise': {'NOUN', 'VERB'},
#              'imports': {'NOUN'},
#              'drop': {'NOUN', 'VERB'},
#              'exports': {'NOUN'},
#              'marc': {'NOUN'},
#              'm.': {'NOUN'},
#              'goloven': {'NOUN'},
#              'economist': {'NOUN'},
#              'manufacturers': {'NOUN'},
#              'hanover': {'NOUN'},
#              'trust': {'NOUN'},
#              'appear': {'VERB'},
#              'indicate': {'VERB'},
#              'sadly': {'ADV'},
#              'deteriorating': {'VERB'},
#              'performance': {'NOUN'},
#              'there': {'ADV', 'DET'},
#              'still': {'ADJ', 'ADV'},
#              'enough': {'ADJ', 'ADV'},
#              'news': {'NOUN'},
#              'justify': {'VERB'},
#              'buying': {'NOUN', 'VERB'},
#              'dollars': {'NOUN'},
#              'canada': {'NOUN'},
#              'widened': {'VERB'},
#              'significantly': {'ADV'},
#              'western': {'ADJ', 'NOUN'},
#              'europe': {'NOUN'},
#              'japan': {'NOUN'},
#              'continues': {'VERB'},
#              'narrow': {'ADJ', 'VERB'},
#              'manufactured': {'ADJ', 'VERB'},
#              'goods': {'NOUN'},
#              'are': {'NOUN', 'VERB'},
#              'rising': {'VERB'},
#              'near-term': {'ADJ'},
#              'path': {'NOUN'},
#              'remains': {'NOUN', 'VERB'},
#              'foggy': {'ADJ'},
#              'currencny': {'NOUN'},
#              'analysts': {'NOUN'},
#              'characterize': {'VERB'},
#              'bewildering': {'VERB'},
#              'late': {'ADJ', 'ADV'},
#              'trading': {'NOUN', 'VERB'},
#              'yesterday': {'ADV', 'NOUN'},
#              'quoted': {'VERB'},
#              'down': {'ADP', 'ADV', 'NOUN', 'PRT'},
#              'sterling': {'NOUN'},
#              'unchanged': {'ADJ'},
#              'tokyo': {'NOUN'},
#              'wednesday': {'NOUN'},
#              'opened': {'VERB'},
#              'fell': {'VERB'},
#              'reports': {'NOUN'},
#              'francisco': {'NOUN'},
#              'earthquake': {'NOUN'},
#              'some': {'DET'},
#              'remain': {'VERB'},
#              'bullish': {'ADJ'},
#              'point': {'NOUN'},
#              'out': {'ADP', 'ADV', 'NOUN', 'PRT'},
#              'despite': {'ADP'},
#              'key': {'ADJ', 'NOUN'},
#              'increases': {'NOUN', 'VERB'},
#              'weeks': {'NOUN'},
#              'aggressive': {'ADJ'},
#              'sales': {'NOUN'},
#              'world': {'NOUN'},
#              'central': {'ADJ', 'NOUN'},
#              'banks': {'NOUN'},
#              '--': {'.'},
#              'traders': {'NOUN'},
#              'estimate': {'NOUN', 'VERB'},
#              'barrage': {'NOUN'},
#              'topped': {'VERB'},
#              '000-point': {'ADJ'},
#              'plunge': {'NOUN', 'VERB'},
#              'note': {'NOUN', 'VERB'},
#              'upper': {'ADJ'},
#              'end': {'NOUN', 'VERB'},
#              'presumed': {'VERB'},
#              'target': {'NOUN'},
#              'zones': {'NOUN'},
#              'established': {'ADJ', 'VERB'},
#              'group': {'NOUN'},
#              'seven': {'NUM'},
#              'g-0': {'NOUN'},
#              'comprises': {'VERB'},
#              'west': {'ADJ', 'NOUN'},
#              'germany': {'NOUN'},
#              'france': {'NOUN'},
#              'italy': {'NOUN'},
#              'so-called': {'ADJ'},
#              'louvre': {'NOUN'},
#              'accord': {'NOUN'},
#              'seen': {'VERB'},
#              'set': {'NOUN', 'VERB'},
#              'ranges': {'NOUN', 'VERB'},
#              'say': {'VERB'},
#              'recent': {'ADJ'},
#              'injection': {'NOUN'},
#              'liquidity': {'NOUN'},
#              'banking': {'NOUN'},
#              'system': {'NOUN'},
#              'anticipate': {'VERB'},
#              'significant': {'ADJ'},
#              'easing': {'NOUN', 'VERB'},
#              'fed': {'NOUN'},
#              'arranged': {'VERB'},
#              'repurchase': {'ADJ', 'VERB'},
#              'agreements': {'NOUN'},
#              'agreement': {'NOUN'},
#              'days': {'NOUN'},
#              'move': {'NOUN', 'VERB'},
#              'injects': {'VERB'},
#              'capital': {'NOUN'},
#              'effort': {'NOUN'},
#              'reassure': {'VERB'},
#              'finanicial': {'ADJ'},
#              'markets': {'NOUN', 'VERB'},
#              'bank': {'NOUN'},
#              'ready': {'ADJ'},
#              'ample': {'ADJ'},
#              'contend': {'VERB'},
#              'loosen': {'VERB'},
#              'credit': {'NOUN'},
#              'nevertheless': {'ADV'},
#              'sends': {'VERB'},
#              'signal': {'NOUN'},
#              'least': {'ADJ'},
#              'now': {'ADJ', 'ADV'},
#              'relaxed': {'VERB'},
#              'grip': {'NOUN'},
#              'add': {'VERB'},
#              'allowed': {'VERB'},
#              'funds': {'NOUN'},
#              'interest': {'NOUN'},
#              'dip': {'VERB'},
#              '0/0': {'NUM'},
#              'levels': {'NOUN'},
#              'just': {'ADV'},
#              'below': {'ADP', 'ADV'},
#              'last': {'ADJ', 'ADV', 'VERB'},
#              'week': {'NOUN'},
#              'overnight': {'ADJ'},
#              'lending': {'NOUN'},
#              'charge': {'NOUN', 'VERB'},
#              'participants': {'NOUN'},
#              'post': {'VERB'},
#              'most': {'ADJ', 'ADV'},
#              'commodity': {'NOUN'},
#              'gold': {'ADJ', 'NOUN'},
#              'delivery': {'NOUN'},
#              'settled': {'VERB'},
#              'ounce': {'NOUN'},
#              'cents': {'NOUN'},
#              'volume': {'NOUN'},
#              'moderate': {'ADJ'},
#              'ounces': {'NOUN'},
#              'early': {'ADJ', 'ADV'},
#              'hong': {'NOUN'},
#              'kong': {'NOUN'},
#              'national': {'ADJ', 'NOUN'},
#              'semiconductor': {'NOUN'},
#              'four-year-old': {'ADJ'},
#              'patent': {'NOUN'},
#              'infringement': {'NOUN'},
#              'case': {'NOUN'},
#              'linear': {'NOUN'},
#              'technology': {'NOUN'},
#              'accepting': {'VERB'},
#              'payment': {'NOUN'},
#              'granting': {'VERB'},
#              'irrevocable': {'ADJ'},
#              'licenses': {'NOUN'},
#              'products': {'NOUN'},
#              'involved': {'ADJ', 'VERB'},
#              'companies': {'NOUN'},
#              'settle': {'VERB'},
#              'future': {'ADJ', 'NOUN'},
#              'property': {'NOUN'},
#              'rights': {'NOUN'},
#              'issues': {'NOUN'},
#              'next': {'ADJ', 'ADP', 'ADV'},
#              'through': {'ADP', 'ADV', 'PRT'},
#              'binding': {'VERB'},
#              'arbitration': {'NOUN'},
#              'analog': {'ADJ'},
#              'integrated': {'ADJ', 'NOUN', 'VERB'},
#              'circuits': {'NOUN'},
#              'applications': {'NOUN'},
#              'consumer': {'NOUN'},
#              'electronics': {'NOUN'},
#              'automobile': {'NOUN'},
#              'electronic': {'ADJ'},
#              'instrumentation': {'NOUN'},
#              'milpitas': {'NOUN'},
#              'settlement': {'NOUN'},
#              'since': {'ADP', 'ADV'},
#              'covered': {'VERB'},
#              'disputed': {'VERB'},
#              'patents': {'NOUN'},
#              'account': {'NOUN', 'VERB'},
#              'annual': {'ADJ', 'NOUN'},
#              'concern': {'NOUN', 'VERB'},
#              'paid': {'VERB'},
#              'santa': {'NOUN'},
#              'clara': {'NOUN'},
#              'remaining': {'VERB'},
#              'equal': {'ADJ', 'VERB'},
#              'installments': {'NOUN'},
#              'eight': {'NUM'},
#              'quarters': {'NOUN'},
#              'payments': {'NOUN'},
#              'impact': {'NOUN'},
#              'coming': {'VERB'},
#              'operating': {'NOUN', 'VERB'},
#              'results': {'NOUN'},
#              'nbc': {'NOUN'},
#              'winning': {'VERB'},
#              'streak': {'NOUN'},
#              'canceled': {'ADJ', 'VERB'},
#              'broadcasting': {'NOUN'},
#              'general': {'ADJ', 'NOUN'},
#              'electric': {'ADJ', 'NOUN'},
#              'record-breaking': {'ADJ'},
#              '00-week': {'ADJ'},
#              'reign': {'NOUN'},
#              'prime-time': {'ADJ'},
#              'ratings': {'NOUN'},
#              'leader': {'NOUN'},
#              'snapped': {'VERB'},
#              'abc-tv': {'NOUN'},
#              'subsidiary': {'NOUN'},
#              'cities/abc': {'NOUN'},
#              'inc': {'NOUN'},
#              'compiled': {'VERB'},
#              'nielsen': {'NOUN'},
#              'abc': {'NOUN'},
#              'broadcast': {'NOUN', 'VERB'},
#              'series': {'NOUN'},
#              'competition': {'NOUN'},
#              'rating': {'NOUN'},
#              'share': {'NOUN', 'VERB'},
#              'followed': {'VERB'},
#              'cbs': {'NOUN'},
#              'network': {'NOUN'},
#              '(': {'.'},
#              'households': {'NOUN'},
#              'percentage': {'NOUN'},
#              'sets': {'NOUN', 'VERB'},
#              ')': {'.'},
#              'games': {'NOUN'},
#              'oakland': {'NOUN'},
#              'athletics': {'NOUN'},
#              'giants': {'NOUN'},
#              'finish': {'VERB'},
#              'top': {'ADJ', 'NOUN', 'VERB'},
#              'instead': {'ADV'},
#              'landed': {'VERB'},
#              'place': {'NOUN'},
#              'highest-rated': {'ADJ'},
#              'show': {'NOUN', 'VERB'},
#              'roseanne': {'NOUN'},
#              'five': {'NUM'},
#              'shows': {'NOUN', 'VERB'},
#              'four': {'NUM'},
#              'held': {'ADJ', 'VERB'},
#              'previous': {'ADJ'},
#              'record': {'NOUN'},
#              'consecutive': {'ADJ'},
#              'victories': {'NOUN'},
#              'during': {'ADP'},
#              '0000-00': {'NUM'},
#              'season': {'NOUN'},
#              'procter': {'NOUN'},
#              'gamble': {'NOUN'},
#              'cincinnati': {'NOUN'},
#              'expanding': {'VERB'},
#              'presence': {'NOUN'},
#              'food': {'NOUN'},
#              'maryland': {'NOUN'},
#              'club': {'NOUN'},
#              'foods': {'NOUN'},
#              'coffee': {'NOUN'},
#              'supplier': {'NOUN'},
#              'led': {'VERB'},
#              'f.': {'NOUN'},
#              'philip': {'NOUN'},
#              'handy': {'NOUN'},
#              'winter': {'NOUN'},
#              'park': {'NOUN'},
#              'fla': {'NOUN'},
#              'terms': {'NOUN'},
#              'disclosed': {'ADJ', 'VERB'},
#              'houston-based': {'ADJ'},
#              'sells': {'VERB'},
#              'under': {'ADP'},
#              'butter-nut': {'NOUN'},
#              'brands': {'NOUN'},
#              'restaurants': {'NOUN'},
#              'hotels': {'NOUN'},
#              'offices': {'NOUN'},
#              'airlines': {'NOUN'},
#              'acquisition': {'NOUN'},
#              'gives': {'VERB'},
#              'production': {'NOUN'},
#              'capacity': {'NOUN'},
#              'stronger': {'ADJ'},
#              'distribution': {'NOUN'},
#              'p&g': {'NOUN'},
#              'folgers': {'NOUN'},
#              'ground': {'NOUN', 'VERB'},
#              'roast': {'NOUN'},
#              'concerns': {'NOUN'},
#              'example': {'NOUN'},
#              'sold': {'VERB'},
#              'limited': {'ADJ', 'VERB'},
#              'large': {'ADJ'},
#              'restaurant': {'NOUN'},
#              'chains': {'NOUN'},
#              'distributes': {'VERB'},
#              'tea': {'NOUN'},
#              'fits': {'VERB'},
#              'tender': {'NOUN', 'VERB'},
#              'leaf': {'NOUN'},
#              'brand': {'NOUN'},
#              'hot': {'ADJ'},
#              'cocoa': {'NOUN'},
#              'completed': {'VERB'},
#              'reviewed': {'VERB'},
#              'purchase': {'NOUN', 'VERB'},
#              'includes': {'VERB'},
#              'coffee-roasting': {'ADJ'},
#              'plant': {'NOUN'},
#              'omaha': {'NOUN'},
#              'neb.': {'NOUN'},
#              'leased': {'VERB'},
#              'facility': {'NOUN'},
#              'houston': {'NOUN'},
#              'macmillan': {'NOUN'},
#              'bloedel': {'NOUN'},
#              'ltd.': {'NOUN'},
#              'borrowed': {'VERB'},
#              'dutch': {'ADJ'},
#              'guilders': {'NOUN'},
#              'us$': {'.'},
#              'institutional': {'ADJ', 'NOUN'},
#              'vancouver': {'NOUN'},
#              'british': {'ADJ', 'NOUN'},
#              'columbia': {'NOUN'},
#              'forest': {'NOUN'},
#              'loan': {'NOUN'},
#              'due': {'ADJ'},
#              'used': {'VERB'},
#              'repay': {'VERB'},
#              'existing': {'VERB'},
#              'short-term': {'ADJ'},
#              'debt': {'NOUN'},
#              'finance': {'NOUN', 'VERB'},
#              'spending': {'NOUN', 'VERB'},
#              'bush': {'NOUN'},
#              'veto': {'NOUN', 'VERB'},
#              'bill': {'NOUN'},
#              'funding': {'NOUN', 'VERB'},
#              'departments': {'NOUN'},
#              'labor': {'NOUN'},
#              'education': {'NOUN'},
#              'health': {'NOUN'},
#              'human': {'ADJ', 'NOUN'},
#              'allow': {'VERB'},
#              'abortions': {'NOUN'},
#              'victims': {'NOUN'},
#              'rape': {'NOUN'},
#              'incest': {'NOUN'},
#              'white': {'ADJ', 'NOUN'},
#              'house': {'NOUN'},
#              'threatened': {'VERB'},
#              'previously': {'ADV'},
#              'put': {'ADJ', 'VERB'},
#              'decision': {'NOUN'},
#              'aides': {'NOUN'},
#              'legislators': {'NOUN'},
#              'searched': {'VERB'},
#              'compromise': {'NOUN'},
#              'tighten': {'VERB'},
#              'requirements': {'NOUN'},
#              'acceptable': {'ADJ'},
#              'press': {'NOUN', 'VERB'},
#              'secretary': {'NOUN'},
#              'marlin': {'NOUN'},
#              'fitzwater': {'NOUN'},
#              'negotiations': {'NOUN'},
#              'lawmakers': {'NOUN'},
#              'ended': {'VERB'},
#              'without': {'ADP'},
#              'success': {'NOUN'},
#              'think': {'VERB'},
#              'extremely': {'ADV'},
#              'difficult': {'ADJ'},
#              'opponents': {'NOUN'},
#              'abortion': {'NOUN'},
#              'issue': {'NOUN', 'VERB'},
#              'round': {'NOUN', 'VERB'},
#              'votes': {'NOUN'},
#              'needed': {'ADJ', 'VERB'},
#              'override': {'VERB'},
#              'prolonged': {'VERB'},
#              'debate': {'NOUN'},
#              'political': {'ADJ'},
#              'maneuvering': {'NOUN'},
#              'holds': {'VERB'},
#              '000.0': {'NUM'},
#              'fiscal': {'ADJ'},
#              'began': {'VERB'},
#              'personally': {'ADV'},
#              'approves': {'VERB'},
#              'cases': {'NOUN'},
#              'danger': {'NOUN'},
#              'mother': {'NOUN'},
#              'opposed': {'VERB'},
#              'medicaid': {'NOUN'},
#              'poor': {'ADJ', 'NOUN'},
#              'women': {'NOUN'},
#              'arguing': {'VERB'},
#              'exceptions': {'NOUN'},
#              'enforced': {'VERB'},
#              'so': {'ADP', 'ADV'},
#              'loosely': {'ADV'},
#              'open': {'ADJ', 'NOUN', 'PRT', 'VERB'},
#              'newspapers': {'NOUN'},
#              'media': {'NOUN'},
#              'intends': {'VERB'},
#              'sell': {'NOUN', 'VERB'},
#              'coast': {'NOUN'},
#              'weekly': {'ADJ'},
#              'newspaper': {'NOUN'},
#              'golden': {'NOUN'},
#              'publishing': {'NOUN'},
#              'highlander': {'NOUN'},
#              'publications': {'NOUN'},
#              'together': {'ADV', 'PRT'},
#              'comprise': {'VERB'},
#              'papers': {'NOUN'},
#              'inquiries': {'NOUN'},
#              'potential': {'ADJ', 'NOUN'},
#              'buyers': {'NOUN'},
#              'expects': {'VERB'},
#              'complete': {'ADJ', 'VERB'},
#              'sale': {'NOUN'},
#              'discuss': {'VERB'},
#              'price': {'NOUN'},
#              'lee': {'NOUN'},
#              'dirks': {'NOUN'},
#              'morgan': {'NOUN'},
#              'help': {'NOUN', 'VERB'},
#              'statutory': {'ADJ'},
#              'managers': {'NOUN'},
#              'dfc': {'NOUN'},
#              'zealand': {'NOUN'},
#              'evaluate': {'VERB'},
#              'failed': {'VERB'},
#              'condition': {'NOUN'},
#              'earlier': {'ADJ', 'ADV'},
#              'month': {'NOUN'},
#              'country': {'NOUN'},
#              'appointed': {'ADJ', 'VERB'},
#              'run': {'NOUN', 'VERB'},
#              'creditors': {'NOUN'},
#              'appoint': {'VERB'},
#              'loan-loss': {'NOUN'},
#              'same': {'ADJ'},
#              ...})

# %%
print('TEXT:',' '.join(sp.instances[3][0]))
print('TAGS:',' '.join(sp.instances[3][1]))

(list(zip(sp.instances[3][0],sp.instances[3][1])))
# Out:
# TEXT: He said Hydro-Quebec already has some `` customers in mind '' for the power that was to be delivered to Maine .
# TAGS: PRON VERB NOUN ADV VERB DET . NOUN ADP NOUN . ADP DET NOUN DET VERB PRT VERB VERB ADP NOUN .
# [('He', 'PRON'),
#  ('said', 'VERB'),
#  ('Hydro-Quebec', 'NOUN'),
#  ('already', 'ADV'),
#  ('has', 'VERB'),
#  ('some', 'DET'),
#  ('``', '.'),
#  ('customers', 'NOUN'),
#  ('in', 'ADP'),
#  ('mind', 'NOUN'),
#  ("''", '.'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('power', 'NOUN'),
#  ('that', 'DET'),
#  ('was', 'VERB'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('delivered', 'VERB'),
#  ('to', 'ADP'),
#  ('Maine', 'NOUN'),
#  ('.', '.')]

# %%
sp.feature_weights
# Out:
# defaultdict(<function __main__.StructuredPerceptron.__init__.<locals>.<lambda>>,
#             {'NEXT_WORD=marshall': defaultdict(float,
#                          {'.': 0.0,
#                           'ADP': -0.025,
#                           'CONJ': 0.0,
#                           'DET': 0.0,
#                           'NOUN': 0.0,
#                           'PRT': 0.025}),
#              'PREV_WORD+WORD=__START__+george': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'BIAS': defaultdict(float,
#                          {'.': -0.1,
#                           'ADJ': 0.6,
#                           'ADP': -0.65,
#                           'ADV': 0.025,
#                           'CONJ': 0.0,
#                           'DET': -0.325,
#                           'NOUN': 1.0,
#                           'NUM': -0.25,
#                           'PRON': -0.025,
#                           'PRT': -0.75,
#                           'VERB': 0.475,
#                           'X': 0.0}),
#              'PREV_WORD=__START__': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.1,
#                           'ADP': 0.225,
#                           'ADV': 0.075,
#                           'CONJ': -0.05,
#                           'DET': 0.025,
#                           'NOUN': -0.175,
#                           'NUM': 0.225,
#                           'PRON': 0.0,
#                           'PRT': -0.05,
#                           'VERB': -0.15,
#                           'X': -0.225}),
#              'NEXT_WORD_PREFIX=mar': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.725,
#                           'ADP': 0.05,
#                           'ADV': -0.325,
#                           'CONJ': 0.0,
#                           'DET': 0.225,
#                           'NOUN': -0.25,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'PRT': 0.025,
#                           'VERB': -0.45}),
#              'PREV_TAG_BIGRAM=__START__+__START__': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.1,
#                           'ADP': 0.225,
#                           'ADV': 0.075,
#                           'CONJ': -0.05,
#                           'DET': 0.025,
#                           'NOUN': -0.175,
#                           'NUM': 0.225,
#                           'PRON': 0.0,
#                           'PRT': -0.05,
#                           'VERB': -0.15,
#                           'X': -0.225}),
#              'WORD=George': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_TAG+SUFFIX=__START___rge': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'LEN<=3=False': defaultdict(float,
#                          {'.': -0.15,
#                           'ADJ': 1.175,
#                           'ADP': -0.625,
#                           'ADV': 0.2,
#                           'CONJ': 0.05,
#                           'DET': -0.85,
#                           'NOUN': 1.4,
#                           'NUM': -0.225,
#                           'PRON': -0.45,
#                           'PRT': -0.725,
#                           'VERB': 0.4,
#                           'X': -0.2}),
#              'WORD+NEXT_WORD=George': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_WORD_PREFIX=__S': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.1,
#                           'ADP': 0.225,
#                           'ADV': 0.075,
#                           'CONJ': -0.05,
#                           'DET': 0.025,
#                           'NOUN': -0.175,
#                           'NUM': 0.225,
#                           'PRON': 0.0,
#                           'PRT': -0.05,
#                           'VERB': -0.15,
#                           'X': -0.225}),
#              'PREFIX=Geo': defaultdict(float, {'ADJ': 0.0, 'NOUN': 0.0}),
#              'NORM_WORD=george': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_TAG=__START__': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.1,
#                           'ADP': 0.225,
#                           'ADV': 0.075,
#                           'CONJ': -0.05,
#                           'DET': 0.025,
#                           'NOUN': -0.175,
#                           'NUM': 0.225,
#                           'PRON': 0.0,
#                           'PRT': -0.05,
#                           'VERB': -0.15,
#                           'X': -0.225}),
#              'SUFFIX+2TAGS=rge+__START__+__START__': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'SUFFIX=rge': defaultdict(float,
#                          {'ADJ': -0.225, 'NOUN': 0.2, 'VERB': 0.025}),
#              'FIRST_LETTER=G': defaultdict(float,
#                          {'ADJ': -0.825, 'NOUN': 0.825, 'VERB': 0.0}),
#              'PREV_TAG+PREFIX=__START___Geo': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'WORD+TAG_BIGRAM=George+__START__+__START__': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'PREFIX+2TAGS=Geo+__START__+__START__': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'PREV_WORD_SUFFIX=T__': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.1,
#                           'ADP': 0.225,
#                           'ADV': 0.075,
#                           'CONJ': -0.05,
#                           'DET': 0.025,
#                           'NOUN': -0.175,
#                           'NUM': 0.225,
#                           'PRON': 0.0,
#                           'PRT': -0.05,
#                           'VERB': -0.15,
#                           'X': -0.225}),
#              'NEXT_WORD_SUFFIX=all': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.0,
#                           'ADP': 0.175,
#                           'ADV': 0.0,
#                           'CONJ': -0.225,
#                           'DET': -0.05,
#                           'NOUN': -0.225,
#                           'NUM': 0.225,
#                           'PRON': 0.0,
#                           'PRT': -0.175,
#                           'VERB': 0.275}),
#              'PREV_TAG+WORD=__START__+George': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'PREV_TAG2=__START__': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.575,
#                           'ADP': -0.1,
#                           'ADV': 0.5,
#                           'CONJ': -0.05,
#                           'DET': 0.725,
#                           'NOUN': -0.35,
#                           'NUM': -0.65,
#                           'PRON': 0.0,
#                           'PRT': -0.425,
#                           'VERB': 0.0,
#                           'X': -0.225}),
#              "NEXT_2WORDS=marshall+'s": defaultdict(float,
#                          {'ADP': -0.025,
#                           'DET': 0.0,
#                           'NOUN': 0.0,
#                           'PRT': 0.025}),
#              'SUFFIX+2TAGS=all+__START__+NOUN': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'PREV_TAG+PREFIX=NOUN_Mar': defaultdict(float, {'NOUN': 0.0}),
#              "NEXT_WORD_PREFIX='s": defaultdict(float,
#                          {'ADJ': -0.65,
#                           'ADP': -0.125,
#                           'ADV': -0.45,
#                           'DET': 0.8,
#                           'NOUN': 0.675,
#                           'NUM': -0.725,
#                           'PRON': 0.925,
#                           'VERB': -0.45}),
#              "NEXT_WORD_SUFFIX='s": defaultdict(float,
#                          {'ADJ': -0.65,
#                           'ADP': -0.125,
#                           'ADV': -0.45,
#                           'DET': 0.8,
#                           'NOUN': 0.675,
#                           'NUM': -0.725,
#                           'PRON': 0.925,
#                           'VERB': -0.45}),
#              "NEXT_2WORDS='s+ghost": defaultdict(float, {'NOUN': 0.0}),
#              'PREV_WORD+WORD=george+marshall': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'SUFFIX=all': defaultdict(float,
#                          {'ADJ': -0.575,
#                           'ADP': -0.525,
#                           'ADV': -0.15,
#                           'DET': 1.075,
#                           'NOUN': 0.025,
#                           'VERB': 0.15}),
#              'PREV_TAG_BIGRAM=__START__+NOUN': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.1,
#                           'ADP': -0.525,
#                           'ADV': 0.3,
#                           'CONJ': 0.0,
#                           'DET': -0.2,
#                           'NOUN': 0.45,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'PRT': 0.175,
#                           'VERB': -0.3}),
#              'PREV_TAG+SUFFIX=NOUN_all': defaultdict(float,
#                          {'DET': 0.0, 'NOUN': -0.05, 'VERB': 0.05}),
#              'WORD+NEXT_WORD=Marshall': defaultdict(float, {'NOUN': 0.0}),
#              'FIRST_LETTER=M': defaultdict(float,
#                          {'ADJ': 0.3,
#                           'ADP': -0.5,
#                           'ADV': 0.625,
#                           'CONJ': -0.225,
#                           'DET': -0.55,
#                           'NOUN': 0.4,
#                           'PRON': 0.0,
#                           'VERB': -0.05}),
#              'PREFIX=Mar': defaultdict(float,
#                          {'ADJ': -0.425, 'ADP': -0.1, 'NOUN': 0.525}),
#              'PREFIX+2TAGS=Mar+__START__+NOUN': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'PREV_TAG=NOUN': defaultdict(float,
#                          {'.': -0.375,
#                           'ADJ': -0.975,
#                           'ADP': 0.2,
#                           'ADV': 0.1,
#                           'CONJ': 0.425,
#                           'DET': -0.825,
#                           'NOUN': 0.45,
#                           'NUM': -0.4,
#                           'PRON': -0.225,
#                           'PRT': 0.8,
#                           'VERB': 0.6,
#                           'X': 0.225}),
#              'WORD+TAG_BIGRAM=Marshall+__START__+NOUN': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'PREV_WORD_SUFFIX=rge': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.2,
#                           'ADP': 0.0,
#                           'DET': 0.0,
#                           'NOUN': -0.225,
#                           'VERB': 0.025}),
#              "NEXT_WORD='s": defaultdict(float,
#                          {'ADJ': -0.65,
#                           'ADP': -0.125,
#                           'ADV': -0.45,
#                           'DET': 0.8,
#                           'NOUN': 0.675,
#                           'NUM': -0.725,
#                           'PRON': 0.925,
#                           'VERB': -0.45}),
#              'PREV_WORD=george': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_WORD_PREFIX=geo': defaultdict(float,
#                          {'.': 0.0,
#                           'ADV': -0.225,
#                           'NOUN': 0.0,
#                           'PRT': 0.0,
#                           'VERB': 0.225}),
#              'NORM_WORD=marshall': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_TAG+WORD=NOUN+Marshall': defaultdict(float, {'NOUN': 0.0}),
#              'WORD=Marshall': defaultdict(float, {'NOUN': 0.0}),
#              'NEXT_WORD_PREFIX=is': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.2,
#                           'ADP': -0.075,
#                           'ADV': -0.825,
#                           'CONJ': 0.0,
#                           'DET': 0.85,
#                           'NOUN': 0.875,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'VERB': -0.625}),
#              'FIRST_LETTER=g': defaultdict(float,
#                          {'ADJ': 1.225,
#                           'ADP': -0.225,
#                           'ADV': -0.65,
#                           'CONJ': -0.225,
#                           'NOUN': 0.5,
#                           'VERB': -0.625,
#                           'X': 0.0}),
#              "PREV_WORD_PREFIX='s": defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.375,
#                           'ADP': -0.275,
#                           'ADV': 0.275,
#                           'CONJ': 0.0,
#                           'DET': -0.225,
#                           'NOUN': 0.65,
#                           'NUM': 0.0,
#                           'PRT': -0.2,
#                           'VERB': -0.6}),
#              'WORD+NEXT_WORD=ghost': defaultdict(float, {'NOUN': 0.0}),
#              'WORD=ghost': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_TAG+PREFIX=PRON_gho': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_TAG+WORD=PRON+ghost': defaultdict(float, {'NOUN': 0.0}),
#              "PREV_WORD+WORD='s+ghost": defaultdict(float, {'NOUN': 0.0}),
#              'SUFFIX=ost': defaultdict(float,
#                          {'ADJ': 0.65,
#                           'ADP': -0.375,
#                           'ADV': 0.5,
#                           'DET': -0.1,
#                           'NOUN': -0.725,
#                           'NUM': -0.225,
#                           'VERB': 0.275,
#                           'X': 0.0}),
#              'NEXT_WORD_SUFFIX=is': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.2,
#                           'ADP': -0.075,
#                           'ADV': -0.825,
#                           'CONJ': 0.0,
#                           'DET': 0.85,
#                           'NOUN': 0.875,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'VERB': -0.625}),
#              'WORD+TAG_BIGRAM=ghost+NOUN+PRON': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'NORM_WORD=ghost': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_TAG_BIGRAM=NOUN+PRON': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.15,
#                           'ADP': -0.175,
#                           'ADV': 0.0,
#                           'DET': 0.0,
#                           'NOUN': -0.425,
#                           'PRON': 0.0,
#                           'PRT': 0.175,
#                           'VERB': 0.575}),
#              'NEXT_WORD=is': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.2,
#                           'ADP': -0.075,
#                           'ADV': -0.825,
#                           'CONJ': 0.0,
#                           'DET': 0.85,
#                           'NOUN': 0.875,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'VERB': -0.625}),
#              'SUFFIX+2TAGS=ost+NOUN+PRON': defaultdict(float, {'NOUN': 0.0}),
#              "PREV_WORD_SUFFIX='s": defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.375,
#                           'ADP': -0.275,
#                           'ADV': 0.275,
#                           'CONJ': 0.0,
#                           'DET': -0.225,
#                           'NOUN': 0.65,
#                           'NUM': 0.0,
#                           'PRT': -0.2,
#                           'VERB': -0.6}),
#              'PREFIX+2TAGS=gho+NOUN+PRON': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_TAG=PRON': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.25,
#                           'ADP': -0.45,
#                           'ADV': -0.225,
#                           'CONJ': -0.15,
#                           'DET': -0.2,
#                           'NOUN': -0.35,
#                           'NUM': -0.275,
#                           'PRON': 0.0,
#                           'PRT': 0.2,
#                           'VERB': 1.2}),
#              "PREV_WORD='s": defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.375,
#                           'ADP': -0.275,
#                           'ADV': 0.275,
#                           'CONJ': 0.0,
#                           'DET': -0.225,
#                           'NOUN': 0.65,
#                           'NUM': 0.0,
#                           'PRT': -0.2,
#                           'VERB': -0.6}),
#              'NEXT_2WORDS=is+much': defaultdict(float, {'NOUN': 0.0}),
#              'PREFIX=gho': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_TAG2=NOUN': defaultdict(float,
#                          {'.': -0.225,
#                           'ADJ': -0.225,
#                           'ADP': -0.35,
#                           'ADV': 0.15,
#                           'CONJ': 0.0,
#                           'DET': 0.225,
#                           'NOUN': 0.95,
#                           'NUM': 0.025,
#                           'PRON': -0.475,
#                           'PRT': -0.6,
#                           'VERB': 0.425,
#                           'X': 0.1}),
#              'PREV_TAG+SUFFIX=PRON_ost': defaultdict(float,
#                          {'ADV': 0.0, 'NOUN': 0.0, 'VERB': 0.0}),
#              'PREV_WORD_PREFIX=mar': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.225,
#                           'ADP': 0.075,
#                           'ADV': -0.325,
#                           'CONJ': 0.0,
#                           'DET': 0.125,
#                           'NOUN': -0.55,
#                           'NUM': 0.0,
#                           'PRON': -0.225,
#                           'PRT': 0.125,
#                           'VERB': 0.55}),
#              "PREFIX='s": defaultdict(float,
#                          {'ADP': -0.425,
#                           'ADV': -0.225,
#                           'NOUN': -0.425,
#                           'PRON': 0.175,
#                           'PRT': 0.45,
#                           'VERB': 0.45}),
#              'LEN<=3=True': defaultdict(float,
#                          {'.': 0.05,
#                           'ADJ': -0.575,
#                           'ADP': -0.025,
#                           'ADV': -0.175,
#                           'CONJ': -0.05,
#                           'DET': 0.525,
#                           'NOUN': -0.4,
#                           'NUM': -0.025,
#                           'PRON': 0.425,
#                           'PRT': -0.025,
#                           'VERB': 0.075,
#                           'X': 0.2}),
#              'PREV_WORD_SUFFIX=all': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.425,
#                           'ADP': -0.625,
#                           'ADV': 0.2,
#                           'CONJ': 0.0,
#                           'DET': 0.575,
#                           'NOUN': -0.175,
#                           'NUM': 0.0,
#                           'PRON': -0.225,
#                           'PRT': 0.275,
#                           'VERB': 0.4}),
#              "SUFFIX+2TAGS='s+NOUN+NOUN": defaultdict(float,
#                          {'ADP': -0.225,
#                           'PRON': -0.225,
#                           'PRT': 0.875,
#                           'VERB': -0.425}),
#              "NORM_WORD='s": defaultdict(float,
#                          {'ADP': -0.425,
#                           'ADV': -0.225,
#                           'NOUN': -0.425,
#                           'PRON': 0.175,
#                           'PRT': 0.45,
#                           'VERB': 0.45}),
#              'PREV_WORD=marshall': defaultdict(float,
#                          {'ADP': 0.0,
#                           'NOUN': 0.0,
#                           'PRON': -0.225,
#                           'PRT': 0.225,
#                           'VERB': 0.0}),
#              'PREV_TAG_BIGRAM=NOUN+NOUN': defaultdict(float,
#                          {'.': -0.225,
#                           'ADJ': -0.325,
#                           'ADP': -0.15,
#                           'ADV': 0.15,
#                           'CONJ': 0.225,
#                           'DET': 0.425,
#                           'NOUN': -0.3,
#                           'NUM': 0.0,
#                           'PRON': -0.225,
#                           'PRT': -0.025,
#                           'VERB': 0.225,
#                           'X': 0.225}),
#              "FIRST_LETTER='": defaultdict(float,
#                          {'.': 0.625,
#                           'ADP': -0.65,
#                           'ADV': -0.4,
#                           'DET': -0.225,
#                           'NOUN': -0.65,
#                           'PRON': 0.175,
#                           'PRT': 0.9,
#                           'VERB': 0.225}),
#              "PREV_TAG+PREFIX=NOUN_'s": defaultdict(float,
#                          {'ADP': -0.425,
#                           'NOUN': -0.225,
#                           'PRON': -0.225,
#                           'PRT': 1.475,
#                           'VERB': -0.6}),
#              "PREV_TAG+SUFFIX=NOUN_'s": defaultdict(float,
#                          {'ADP': -0.425,
#                           'NOUN': -0.225,
#                           'PRON': -0.225,
#                           'PRT': 1.475,
#                           'VERB': -0.6}),
#              "WORD+NEXT_WORD='s": defaultdict(float,
#                          {'ADP': -0.425,
#                           'ADV': -0.225,
#                           'NOUN': -0.425,
#                           'PRON': 0.175,
#                           'PRT': 0.45,
#                           'VERB': 0.45}),
#              'NEXT_WORD_SUFFIX=ost': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.2,
#                           'ADP': -0.55,
#                           'ADV': -0.25,
#                           'CONJ': 0.0,
#                           'DET': 0.425,
#                           'NOUN': -0.2,
#                           'PRON': -0.225,
#                           'PRT': 0.6,
#                           'VERB': 0.0}),
#              'NEXT_WORD_PREFIX=gho': defaultdict(float,
#                          {'ADJ': 0.0,
#                           'ADP': -0.425,
#                           'DET': 0.425,
#                           'PRON': -0.225,
#                           'PRT': 0.225}),
#              "PREV_TAG+WORD=NOUN+'s": defaultdict(float,
#                          {'ADP': -0.425,
#                           'NOUN': -0.225,
#                           'PRON': -0.225,
#                           'PRT': 1.475,
#                           'VERB': -0.6}),
#              'NEXT_WORD=ghost': defaultdict(float,
#                          {'ADJ': 0.0,
#                           'ADP': -0.425,
#                           'DET': 0.425,
#                           'PRON': -0.225,
#                           'PRT': 0.225}),
#              "WORD+TAG_BIGRAM='s+NOUN+NOUN": defaultdict(float,
#                          {'ADP': -0.225,
#                           'PRON': -0.225,
#                           'PRT': 0.875,
#                           'VERB': -0.425}),
#              'NEXT_2WORDS=ghost+is': defaultdict(float,
#                          {'PRON': -0.225, 'PRT': 0.225}),
#              "SUFFIX='s": defaultdict(float,
#                          {'ADP': -0.425,
#                           'ADV': -0.225,
#                           'NOUN': -0.425,
#                           'PRON': 0.175,
#                           'PRT': 0.45,
#                           'VERB': 0.45}),
#              "PREV_WORD+WORD=marshall+'s": defaultdict(float,
#                          {'PRON': -0.225, 'PRT': 0.225}),
#              "WORD='s": defaultdict(float,
#                          {'ADP': -0.425,
#                           'ADV': -0.225,
#                           'NOUN': -0.425,
#                           'PRON': 0.175,
#                           'PRT': 0.45,
#                           'VERB': 0.45}),
#              "PREFIX+2TAGS='s+NOUN+NOUN": defaultdict(float,
#                          {'ADP': -0.225,
#                           'PRON': -0.225,
#                           'PRT': 0.875,
#                           'VERB': -0.425}),
#              'PREFIX+2TAGS=to+PRON+ADJ': defaultdict(float,
#                          {'ADP': 0.225, 'PRON': -0.225, 'PRT': 0.0}),
#              'NEXT_2WORDS=keep+happy': defaultdict(float,
#                          {'PRON': -0.225, 'PRT': 0.225}),
#              'PREV_TAG+PREFIX=ADJ_to': defaultdict(float,
#                          {'ADP': 0.2, 'PRON': -0.225, 'PRT': 0.025}),
#              'PREV_WORD_SUFFIX=ult': defaultdict(float,
#                          {'.': 0.0,
#                           'ADP': 0.425,
#                           'NOUN': 0.0,
#                           'PRON': -0.225,
#                           'PRT': -0.2}),
#              'NEXT_WORD=keep': defaultdict(float,
#                          {'ADP': -0.225,
#                           'CONJ': 0.0,
#                           'DET': -0.2,
#                           'PRON': -0.225,
#                           'PRT': 0.65,
#                           'VERB': 0.0}),
#              'PREV_TAG+SUFFIX=ADJ_to': defaultdict(float,
#                          {'ADP': 0.2, 'PRON': -0.225, 'PRT': 0.025}),
#              'PREV_WORD_PREFIX=dif': defaultdict(float,
#                          {'.': 0.0,
#                           'ADP': 0.0,
#                           'CONJ': 0.0,
#                           'NOUN': 0.0,
#                           'PRON': -0.225,
#                           'PRT': 0.225,
#                           'VERB': 0.0}),
#              'NEXT_WORD_SUFFIX=eep': defaultdict(float,
#                          {'ADP': -0.225,
#                           'ADV': 0.0,
#                           'CONJ': 0.0,
#                           'DET': -0.2,
#                           'PRON': -0.225,
#                           'PRT': 0.65,
#                           'VERB': 0.0}),
#              'WORD+NEXT_WORD=to': defaultdict(float,
#                          {'ADP': 0.75,
#                           'ADV': -0.35,
#                           'DET': -0.45,
#                           'NOUN': -0.225,
#                           'PRON': -0.225,
#                           'PRT': 0.8,
#                           'VERB': -0.3}),
#              'PREV_TAG=ADJ': defaultdict(float,
#                          {'.': 0.225,
#                           'ADJ': -0.05,
#                           'ADP': 0.475,
#                           'ADV': -0.375,
#                           'CONJ': 0.0,
#                           'DET': -0.2,
#                           'NOUN': 1.55,
#                           'NUM': 0.025,
#                           'PRON': -0.45,
#                           'PRT': -0.125,
#                           'VERB': -1.075}),
#              'PREV_TAG2=PRON': defaultdict(float,
#                          {'.': 0.225,
#                           'ADJ': -0.5,
#                           'ADP': 0.0,
#                           'ADV': -0.025,
#                           'CONJ': 0.0,
#                           'DET': -0.225,
#                           'NOUN': 0.225,
#                           'NUM': -0.425,
#                           'PRON': 0.0,
#                           'PRT': 0.25,
#                           'VERB': 0.475}),
#              'PREV_WORD+WORD=difficult+to': defaultdict(float,
#                          {'PRON': -0.225, 'PRT': 0.225}),
#              'WORD+TAG_BIGRAM=to+PRON+ADJ': defaultdict(float,
#                          {'ADP': 0.225, 'PRON': -0.225, 'PRT': 0.0}),
#              'FIRST_LETTER=t': defaultdict(float,
#                          {'.': -0.2,
#                           'ADJ': -0.4,
#                           'ADP': 1.275,
#                           'ADV': -0.5,
#                           'CONJ': 0.225,
#                           'DET': 1.275,
#                           'NOUN': -1.075,
#                           'NUM': 0.425,
#                           'PRON': -0.225,
#                           'PRT': 0.0,
#                           'VERB': -0.8}),
#              'SUFFIX=to': defaultdict(float,
#                          {'ADP': 0.75,
#                           'ADV': -0.35,
#                           'DET': -0.45,
#                           'NOUN': -0.225,
#                           'PRON': -0.225,
#                           'PRT': 0.8,
#                           'VERB': -0.3}),
#              'PREFIX=to': defaultdict(float,
#                          {'ADP': 0.75,
#                           'ADV': -0.35,
#                           'DET': -0.45,
#                           'NOUN': -0.225,
#                           'PRON': -0.225,
#                           'PRT': 0.8,
#                           'VERB': -0.3}),
#              'NEXT_WORD_PREFIX=kee': defaultdict(float,
#                          {'ADP': -0.225,
#                           'CONJ': 0.0,
#                           'DET': -0.2,
#                           'NOUN': 0.0,
#                           'PRON': -0.225,
#                           'PRT': 0.65,
#                           'VERB': 0.0}),
#              'PREV_TAG+WORD=ADJ+to': defaultdict(float,
#                          {'ADP': 0.2, 'PRON': -0.225, 'PRT': 0.025}),
#              'SUFFIX+2TAGS=to+PRON+ADJ': defaultdict(float,
#                          {'ADP': 0.225, 'PRON': -0.225, 'PRT': 0.0}),
#              'PREV_WORD=difficult': defaultdict(float,
#                          {'.': 0.0, 'ADP': 0.0, 'PRON': -0.225, 'PRT': 0.225}),
#              'WORD=to': defaultdict(float,
#                          {'ADP': 0.75,
#                           'ADV': -0.35,
#                           'DET': -0.45,
#                           'NOUN': -0.225,
#                           'PRON': -0.225,
#                           'PRT': 0.8,
#                           'VERB': -0.3}),
#              'PREV_TAG_BIGRAM=PRON+ADJ': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.025,
#                           'ADP': 0.225,
#                           'ADV': -0.225,
#                           'CONJ': 0.0,
#                           'DET': 0.0,
#                           'NOUN': 0.425,
#                           'NUM': 0.0,
#                           'PRON': -0.225,
#                           'PRT': 0.0,
#                           'VERB': -0.225}),
#              'NORM_WORD=to': defaultdict(float,
#                          {'ADP': 0.775,
#                           'ADV': -0.575,
#                           'DET': -0.65,
#                           'NOUN': -0.225,
#                           'PRON': -0.225,
#                           'PRT': 1.2,
#                           'VERB': -0.3}),
#              'PREV_TAG+PREFIX=NOUN_is': defaultdict(float, {'VERB': 0.0}),
#              'WORD+TAG_BIGRAM=is+PRON+NOUN': defaultdict(float, {'VERB': 0.0}),
#              'SUFFIX+2TAGS=is+PRON+NOUN': defaultdict(float, {'VERB': 0.0}),
#              'PREV_WORD_SUFFIX=ost': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.375,
#                           'ADP': 0.0,
#                           'ADV': 0.725,
#                           'CONJ': 0.0,
#                           'DET': 0.0,
#                           'NOUN': -0.2,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'PRT': -0.45,
#                           'VERB': -0.45}),
#              'PREV_TAG_BIGRAM=PRON+NOUN': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.15,
#                           'ADP': -0.225,
#                           'ADV': -0.275,
#                           'CONJ': 0.0,
#                           'DET': -0.225,
#                           'NOUN': 0.4,
#                           'PRON': 0.0,
#                           'PRT': 0.525,
#                           'VERB': -0.35}),
#              'PREV_TAG+WORD=NOUN+is': defaultdict(float, {'VERB': 0.0}),
#              'WORD=is': defaultdict(float, {'VERB': 0.0}),
#              'PREFIX=is': defaultdict(float, {'VERB': 0.0}),
#              'PREV_WORD_PREFIX=gho': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.425,
#                           'ADP': 0.0,
#                           'ADV': 0.05,
#                           'CONJ': 0.0,
#                           'NOUN': -0.025,
#                           'PRT': -0.225,
#                           'VERB': -0.225}),
#              'SUFFIX=is': defaultdict(float, {'VERB': 0.0}),
#              'FIRST_LETTER=i': defaultdict(float,
#                          {'ADJ': 1.25,
#                           'ADP': 0.4,
#                           'ADV': -0.5,
#                           'DET': -0.225,
#                           'NOUN': -0.875,
#                           'PRON': -0.075,
#                           'PRT': -0.275,
#                           'VERB': 0.3}),
#              'NEXT_WORD=much': defaultdict(float,
#                          {'ADJ': -0.225,
#                           'ADP': -0.325,
#                           'ADV': 0.6,
#                           'DET': -0.275,
#                           'NOUN': 0.225,
#                           'VERB': 0.0}),
#              'NEXT_WORD_PREFIX=muc': defaultdict(float,
#                          {'ADJ': -0.225,
#                           'ADP': -0.325,
#                           'ADV': 0.6,
#                           'DET': -0.275,
#                           'NOUN': 0.225,
#                           'VERB': 0.0}),
#              'PREFIX+2TAGS=is+PRON+NOUN': defaultdict(float, {'VERB': 0.0}),
#              'NEXT_2WORDS=much+more': defaultdict(float, {'VERB': 0.0}),
#              'WORD+NEXT_WORD=is': defaultdict(float, {'VERB': 0.0}),
#              'PREV_WORD+WORD=ghost+is': defaultdict(float, {'VERB': 0.0}),
#              'NEXT_WORD_SUFFIX=uch': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.075,
#                           'ADP': 0.075,
#                           'ADV': 0.375,
#                           'CONJ': 0.0,
#                           'DET': -0.275,
#                           'NOUN': 0.075,
#                           'PRT': -0.175,
#                           'VERB': 0.0}),
#              'PREV_TAG+SUFFIX=NOUN_is': defaultdict(float, {'VERB': 0.0}),
#              'NORM_WORD=is': defaultdict(float, {'VERB': 0.0}),
#              'PREV_WORD=ghost': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.425,
#                           'ADP': 0.0,
#                           'ADV': 0.05,
#                           'CONJ': 0.0,
#                           'NOUN': -0.025,
#                           'PRT': -0.225,
#                           'VERB': -0.225}),
#              'PREV_WORD=to': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.15,
#                           'ADP': -0.425,
#                           'ADV': -0.25,
#                           'DET': 0.15,
#                           'NOUN': -1.2,
#                           'NUM': 0.2,
#                           'PRON': 0.0,
#                           'VERB': 1.675}),
#              'WORD+TAG_BIGRAM=keep+ADJ+PRON': defaultdict(float,
#                          {'VERB': 0.0}),
#              'WORD=keep': defaultdict(float, {'VERB': 0.0}),
#              'NEXT_WORD_SUFFIX=ppy': defaultdict(float,
#                          {'DET': 0.0, 'VERB': 0.0}),
#              'NEXT_2WORDS=happy+.': defaultdict(float, {'VERB': 0.0}),
#              'SUFFIX=eep': defaultdict(float,
#                          {'ADJ': 0.0, 'NOUN': 0.0, 'VERB': 0.0}),
#              'PREV_TAG_BIGRAM=ADJ+PRON': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.0,
#                           'ADP': 0.0,
#                           'ADV': 0.0,
#                           'NOUN': 0.0,
#                           'PRON': 0.0,
#                           'VERB': 0.0}),
#              'PREV_TAG2=ADJ': defaultdict(float,
#                          {'.': -0.225,
#                           'ADJ': 0.075,
#                           'ADP': -0.375,
#                           'ADV': 0.325,
#                           'CONJ': 0.0,
#                           'DET': 0.125,
#                           'NOUN': 0.25,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'PRT': 0.025,
#                           'VERB': -0.2,
#                           'X': 0.0}),
#              'PREV_TAG+PREFIX=PRON_kee': defaultdict(float, {'VERB': 0.0}),
#              'PREV_WORD+WORD=to+keep': defaultdict(float, {'VERB': 0.0}),
#              'PREFIX=kee': defaultdict(float, {'VERB': 0.0}),
#              'PREFIX+2TAGS=kee+ADJ+PRON': defaultdict(float, {'VERB': 0.0}),
#              'PREV_WORD_SUFFIX=to': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.15,
#                           'ADP': -0.425,
#                           'ADV': -0.25,
#                           'DET': 0.15,
#                           'NOUN': -1.2,
#                           'NUM': 0.2,
#                           'PRON': 0.0,
#                           'VERB': 1.675}),
#              'PREV_TAG+WORD=PRON+keep': defaultdict(float, {'VERB': 0.0}),
#              'NEXT_WORD=happy': defaultdict(float, {'VERB': 0.0}),
#              'PREV_TAG+SUFFIX=PRON_eep': defaultdict(float, {'VERB': 0.0}),
#              'PREV_WORD_PREFIX=to': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.15,
#                           'ADP': -0.425,
#                           'ADV': -0.25,
#                           'DET': 0.15,
#                           'NOUN': -1.2,
#                           'NUM': 0.2,
#                           'PRON': 0.0,
#                           'VERB': 1.675}),
#              'SUFFIX+2TAGS=eep+ADJ+PRON': defaultdict(float, {'VERB': 0.0}),
#              'WORD+NEXT_WORD=keep': defaultdict(float, {'VERB': 0.0}),
#              'NORM_WORD=keep': defaultdict(float, {'VERB': 0.0}),
#              'NEXT_WORD_PREFIX=hap': defaultdict(float,
#                          {'.': 0.0, 'PRON': 0.0, 'VERB': 0.0}),
#              'FIRST_LETTER=k': defaultdict(float,
#                          {'ADJ': 0.25,
#                           'CONJ': -0.225,
#                           'NOUN': -0.025,
#                           'VERB': 0.0}),
#              'PREV_TAG=VERB': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.15,
#                           'ADP': -0.35,
#                           'ADV': -0.05,
#                           'CONJ': 0.0,
#                           'DET': 0.15,
#                           'NOUN': -0.8,
#                           'NUM': -0.525,
#                           'PRON': 0.5,
#                           'PRT': 1.0,
#                           'VERB': 0.225,
#                           'X': 0.0}),
#              'NEXT_WORD_PREFIX=mor': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.225,
#                           'ADP': 0.25,
#                           'ADV': 0.225,
#                           'CONJ': 0.0,
#                           'DET': 0.225,
#                           'NOUN': -0.225,
#                           'NUM': 0.0,
#                           'PRON': -0.225,
#                           'PRT': -0.25,
#                           'VERB': 0.225}),
#              'NORM_WORD=much': defaultdict(float,
#                          {'ADJ': 0.325,
#                           'ADP': -0.175,
#                           'ADV': 1.375,
#                           'DET': -0.225,
#                           'NOUN': -0.45,
#                           'NUM': -0.2,
#                           'PRON': -0.225,
#                           'VERB': -0.425}),
#              'NEXT_WORD=more': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.225,
#                           'ADP': 0.25,
#                           'ADV': 0.225,
#                           'CONJ': 0.0,
#                           'DET': 0.225,
#                           'NOUN': -0.225,
#                           'NUM': 0.0,
#                           'PRON': -0.225,
#                           'PRT': -0.25,
#                           'VERB': 0.225}),
#              'WORD+NEXT_WORD=much': defaultdict(float,
#                          {'ADJ': 0.325,
#                           'ADV': 0.75,
#                           'NOUN': -0.225,
#                           'NUM': -0.2,
#                           'PRON': -0.225,
#                           'VERB': -0.425}),
#              'FIRST_LETTER=m': defaultdict(float,
#                          {'ADJ': 1.45,
#                           'ADP': -0.225,
#                           'ADV': 0.325,
#                           'CONJ': 0.0,
#                           'DET': 0.275,
#                           'NOUN': -0.875,
#                           'NUM': -0.425,
#                           'PRON': -0.45,
#                           'PRT': -0.425,
#                           'VERB': 0.35}),
#              'WORD=much': defaultdict(float,
#                          {'ADJ': 0.325,
#                           'ADV': 0.75,
#                           'NOUN': -0.225,
#                           'NUM': -0.2,
#                           'PRON': -0.225,
#                           'VERB': -0.425}),
#              'SUFFIX+2TAGS=uch+NOUN+VERB': defaultdict(float,
#                          {'ADJ': -0.425, 'ADV': 0.65, 'PRON': -0.225}),
#              'PREV_WORD=is': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.25,
#                           'ADP': -0.225,
#                           'ADV': -0.05,
#                           'DET': -0.15,
#                           'NOUN': 0.325,
#                           'NUM': -0.3,
#                           'PRON': -0.225,
#                           'PRT': 0.275,
#                           'VERB': 0.1,
#                           'X': 0.0}),
#              'PREV_WORD_SUFFIX=is': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.25,
#                           'ADP': -0.225,
#                           'ADV': -0.05,
#                           'DET': -0.15,
#                           'NOUN': 0.325,
#                           'NUM': -0.3,
#                           'PRON': -0.225,
#                           'PRT': 0.275,
#                           'VERB': 0.1,
#                           'X': 0.0}),
#              'SUFFIX=uch': defaultdict(float,
#                          {'ADJ': 1.425,
#                           'ADP': -0.375,
#                           'ADV': 0.7,
#                           'DET': 0.125,
#                           'NOUN': -0.825,
#                           'NUM': -0.2,
#                           'PRON': -0.225,
#                           'VERB': -0.625}),
#              'PREV_TAG+SUFFIX=VERB_uch': defaultdict(float,
#                          {'ADJ': 0.2,
#                           'ADV': 0.1,
#                           'DET': 0.35,
#                           'NOUN': -0.225,
#                           'PRON': -0.225,
#                           'VERB': -0.2}),
#              'PREFIX+2TAGS=muc+NOUN+VERB': defaultdict(float,
#                          {'ADJ': -0.425, 'ADV': 0.65, 'PRON': -0.225}),
#              'PREFIX=muc': defaultdict(float,
#                          {'ADJ': 0.325,
#                           'ADV': 0.75,
#                           'NOUN': -0.225,
#                           'NUM': -0.2,
#                           'PRON': -0.225,
#                           'VERB': -0.425}),
#              'PREV_WORD+WORD=is+much': defaultdict(float,
#                          {'ADJ': -0.2, 'ADV': 0.425, 'PRON': -0.225}),
#              'PREV_TAG+PREFIX=VERB_muc': defaultdict(float,
#                          {'ADJ': 0.125, 'ADV': 0.1, 'PRON': -0.225}),
#              'NEXT_WORD_SUFFIX=ore': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.775,
#                           'ADP': 0.075,
#                           'ADV': 0.8,
#                           'CONJ': 0.0,
#                           'DET': 0.225,
#                           'NOUN': -0.25,
#                           'NUM': 0.0,
#                           'PRON': -0.225,
#                           'PRT': -0.075,
#                           'VERB': 0.225}),
#              'PREV_WORD_PREFIX=is': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.25,
#                           'ADP': -0.225,
#                           'ADV': -0.05,
#                           'DET': -0.15,
#                           'NOUN': 0.325,
#                           'NUM': -0.3,
#                           'PRON': -0.225,
#                           'PRT': 0.275,
#                           'VERB': 0.1,
#                           'X': 0.0}),
#              'WORD+TAG_BIGRAM=much+NOUN+VERB': defaultdict(float,
#                          {'ADJ': -0.425, 'ADV': 0.65, 'PRON': -0.225}),
#              'PREV_TAG_BIGRAM=NOUN+VERB': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.2,
#                           'ADP': 0.0,
#                           'ADV': 0.4,
#                           'CONJ': -0.225,
#                           'DET': -0.2,
#                           'NOUN': -0.275,
#                           'NUM': -0.425,
#                           'PRON': -0.225,
#                           'PRT': 0.55,
#                           'VERB': 0.6}),
#              'NEXT_2WORDS=more+difficult': defaultdict(float,
#                          {'ADV': 0.225, 'NOUN': 0.0, 'PRON': -0.225}),
#              'PREV_TAG+WORD=VERB+much': defaultdict(float,
#                          {'ADJ': 0.125, 'ADV': 0.1, 'PRON': -0.225}),
#              'PREV_WORD_SUFFIX=uch': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.325,
#                           'ADP': 0.425,
#                           'ADV': -0.5,
#                           'DET': 0.0,
#                           'NOUN': 0.4,
#                           'PRON': -0.225,
#                           'PRT': -0.2,
#                           'VERB': -0.225}),
#              'NEXT_WORD=difficult': defaultdict(float,
#                          {'ADJ': -0.65,
#                           'ADV': 0.875,
#                           'PRON': -0.225,
#                           'VERB': 0.0}),
#              'PREV_WORD=much': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.325,
#                           'ADP': 0.2,
#                           'ADV': -0.275,
#                           'NOUN': 0.4,
#                           'PRON': -0.225,
#                           'PRT': -0.2,
#                           'VERB': -0.225}),
#              'PREV_WORD_PREFIX=muc': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.325,
#                           'ADP': 0.2,
#                           'ADV': -0.275,
#                           'NOUN': 0.4,
#                           'PRON': -0.225,
#                           'PRT': -0.2,
#                           'VERB': -0.225}),
#              'SUFFIX+2TAGS=ore+VERB+PRON': defaultdict(float,
#                          {'ADV': 0.225, 'NOUN': 0.0, 'PRON': -0.225}),
#              'PREFIX+2TAGS=mor+VERB+PRON': defaultdict(float,
#                          {'ADV': 0.225, 'PRON': -0.225}),
#              'NEXT_WORD_PREFIX=dif': defaultdict(float,
#                          {'ADJ': -0.45,
#                           'ADP': 0.625,
#                           'ADV': 0.675,
#                           'DET': 0.0,
#                           'NOUN': 0.0,
#                           'PRON': -0.225,
#                           'PRT': -0.625,
#                           'VERB': 0.0}),
#              'PREV_TAG_BIGRAM=VERB+PRON': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.425,
#                           'ADP': 0.2,
#                           'ADV': 0.05,
#                           'CONJ': 0.0,
#                           'DET': 0.025,
#                           'NOUN': 0.4,
#                           'NUM': 0.175,
#                           'PRON': -0.225,
#                           'PRT': 0.225,
#                           'VERB': -0.425}),
#              'PREFIX=mor': defaultdict(float,
# ...
#                          {'.': 0.0,
#                           'ADJ': 0.225,
#                           'ADP': 0.225,
#                           'ADV': -0.225,
#                           'NOUN': 0.175,
#                           'PRON': 0.0,
#                           'PRT': -0.225,
#                           'VERB': -0.175}),
#              'SUFFIX+2TAGS=,+DET+ADV': defaultdict(float, {'.': 0.0}),
#              'PREV_WORD_SUFFIX=are': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.475,
#                           'ADP': -0.275,
#                           'ADV': 0.2,
#                           'CONJ': 0.0,
#                           'DET': 0.225,
#                           'NOUN': 0.175,
#                           'NUM': -0.225,
#                           'PRON': 0.0,
#                           'PRT': -1.025,
#                           'VERB': 0.45}),
#              'PREV_TAG_BIGRAM=DET+ADV': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.725,
#                           'ADP': 0.2,
#                           'ADV': 0.0,
#                           'CONJ': 0.0,
#                           'DET': -0.225,
#                           'NOUN': -0.425,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'PRT': -0.2,
#                           'VERB': -0.075}),
#              'NEXT_2WORDS=or+00': defaultdict(float, {'.': 0.0, 'NOUN': 0.0}),
#              'NEXT_WORD=a': defaultdict(float,
#                          {'.': -0.2,
#                           'ADJ': -1.275,
#                           'ADP': 1.25,
#                           'ADV': 0.025,
#                           'CONJ': 0.225,
#                           'DET': 0.1,
#                           'NOUN': -0.35,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'PRT': -0.5,
#                           'VERB': 0.725,
#                           'X': 0.0}),
#              'PREV_TAG_BIGRAM=ADP+DET': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.375,
#                           'ADP': 0.0,
#                           'ADV': 0.1,
#                           'CONJ': 0.0,
#                           'DET': -0.175,
#                           'NOUN': 0.5,
#                           'NUM': -0.225,
#                           'PRON': 0.0,
#                           'PRT': -0.225,
#                           'VERB': -0.35}),
#              'SUFFIX+2TAGS=,+ADP+DET': defaultdict(float, {'.': 0.0}),
#              'PREV_TAG+PREFIX=DET_,': defaultdict(float, {'.': 0.0}),
#              'PREFIX+2TAGS=,+ADP+DET': defaultdict(float, {'.': 0.0}),
#              'NEXT_2WORDS=a+year': defaultdict(float,
#                          {'.': 0.0,
#                           'ADP': 0.0,
#                           'NOUN': 0.0,
#                           'NUM': 0.0,
#                           'VERB': 0.0}),
#              'PREV_TAG+WORD=DET+,': defaultdict(float, {'.': 0.0}),
#              'NEXT_WORD_PREFIX=a': defaultdict(float,
#                          {'.': -0.2,
#                           'ADJ': -1.275,
#                           'ADP': 1.25,
#                           'ADV': 0.025,
#                           'CONJ': 0.225,
#                           'DET': 0.1,
#                           'NOUN': -0.35,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'PRT': -0.5,
#                           'VERB': 0.725,
#                           'X': 0.0}),
#              'PREV_TAG+SUFFIX=DET_,': defaultdict(float, {'.': 0.0}),
#              'NEXT_WORD_SUFFIX=a': defaultdict(float,
#                          {'.': -0.2,
#                           'ADJ': -1.275,
#                           'ADP': 1.25,
#                           'ADV': 0.025,
#                           'CONJ': 0.225,
#                           'DET': 0.1,
#                           'NOUN': -0.35,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'PRT': -0.5,
#                           'VERB': 0.725,
#                           'X': 0.0}),
#              'WORD+TAG_BIGRAM=,+ADP+DET': defaultdict(float, {'.': 0.0}),
#              'PREFIX+2TAGS=.+NOUN+ADJ': defaultdict(float, {'.': 0.0}),
#              'SUFFIX+2TAGS=.+NOUN+ADJ': defaultdict(float, {'.': 0.0}),
#              'PREV_WORD_PREFIX=ear': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.225,
#                           'ADP': -0.2,
#                           'ADV': 0.0,
#                           'CONJ': 0.0,
#                           'DET': 0.0,
#                           'NOUN': 0.3,
#                           'PRT': 0.2,
#                           'VERB': -0.525}),
#              'PREV_TAG_BIGRAM=NOUN+ADJ': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.375,
#                           'ADP': -0.275,
#                           'ADV': 0.225,
#                           'CONJ': 0.0,
#                           'DET': 0.1,
#                           'NOUN': -0.225,
#                           'NUM': 0.0,
#                           'PRT': -0.025,
#                           'VERB': -0.175}),
#              'PREV_WORD=earlier': defaultdict(float,
#                          {'.': 0.0,
#                           'ADP': 0.0,
#                           'CONJ': 0.0,
#                           'DET': 0.0,
#                           'NOUN': 0.0}),
#              'PREV_WORD_SUFFIX=ier': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.225,
#                           'ADP': 0.0,
#                           'ADV': 0.225,
#                           'CONJ': 0.0,
#                           'DET': 0.0,
#                           'NOUN': 0.0,
#                           'PRT': 0.0,
#                           'VERB': 0.0}),
#              'WORD+TAG_BIGRAM=.+NOUN+ADJ': defaultdict(float, {'.': 0.0}),
#              'PREV_WORD+WORD=earlier+.': defaultdict(float, {'.': 0.0}),
#              'PREV_TAG_BIGRAM=ADV+.': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.05,
#                           'ADP': 0.475,
#                           'ADV': -0.625,
#                           'CONJ': 0.0,
#                           'DET': -0.125,
#                           'NOUN': 0.175,
#                           'NUM': -0.075,
#                           'PRON': 0.075,
#                           'VERB': 0.05,
#                           'X': 0.0}),
#              'PREFIX=Hon': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_TAG+WORD=.+Honeywell': defaultdict(float, {'NOUN': 0.0}),
#              'WORD+NEXT_WORD=Honeywell': defaultdict(float, {'NOUN': 0.0}),
#              'WORD+TAG_BIGRAM=Honeywell+ADV+.': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'NEXT_2WORDS=reported+earnings': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'NEXT_WORD_PREFIX=rep': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -0.225,
#                           'ADP': -1.025,
#                           'ADV': 0.3,
#                           'CONJ': 0.0,
#                           'DET': 0.0,
#                           'NOUN': 0.125,
#                           'PRON': 0.0,
#                           'PRT': 0.825,
#                           'VERB': 0.0}),
#              'PREV_WORD+WORD=,+honeywell': defaultdict(float, {'NOUN': 0.0}),
#              'NEXT_WORD_SUFFIX=ted': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': -1.6,
#                           'ADP': 0.225,
#                           'ADV': 0.775,
#                           'CONJ': 0.0,
#                           'DET': 0.0,
#                           'NOUN': 0.3,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'PRT': -0.425,
#                           'VERB': 0.725,
#                           'X': 0.0}),
#              'SUFFIX=ell': defaultdict(float,
#                          {'ADJ': -0.175,
#                           'ADP': -0.2,
#                           'ADV': 0.875,
#                           'NOUN': -0.425,
#                           'PRT': -0.175,
#                           'VERB': 0.1}),
#              'PREV_TAG+PREFIX=._Hon': defaultdict(float, {'NOUN': 0.0}),
#              'WORD=Honeywell': defaultdict(float, {'NOUN': 0.0}),
#              'PREFIX+2TAGS=Hon+ADV+.': defaultdict(float, {'NOUN': 0.0}),
#              'NEXT_WORD=reported': defaultdict(float,
#                          {'.': 0.0,
#                           'ADP': -0.2,
#                           'ADV': 0.075,
#                           'NOUN': 0.125,
#                           'PRON': 0.0,
#                           'VERB': 0.0}),
#              'SUFFIX+2TAGS=ell+ADV+.': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_TAG+SUFFIX=._ell': defaultdict(float,
#                          {'ADV': 0.225, 'NOUN': -0.225, 'VERB': 0.0}),
#              'NORM_WORD=honeywell': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_TAG+PREFIX=VERB_ear': defaultdict(float,
#                          {'ADJ': -0.625,
#                           'ADV': 0.625,
#                           'NOUN': 0.0,
#                           'VERB': 0.0}),
#              'PREV_WORD_PREFIX=rep': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.225,
#                           'ADP': -0.2,
#                           'ADV': 0.0,
#                           'CONJ': 0.0,
#                           'DET': -0.225,
#                           'NOUN': -0.15,
#                           'NUM': 0.0,
#                           'PRON': 0.0,
#                           'VERB': 0.35}),
#              'NORM_WORD=earnings': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_WORD=reported': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.0,
#                           'ADP': 0.225,
#                           'ADV': 0.0,
#                           'DET': -0.225,
#                           'NOUN': -0.15,
#                           'PRON': 0.0,
#                           'VERB': 0.15}),
#              'PREFIX+2TAGS=ear+NOUN+VERB': defaultdict(float,
#                          {'ADJ': -0.425,
#                           'ADV': 0.425,
#                           'NOUN': 0.0,
#                           'VERB': 0.0}),
#              'WORD=earnings': defaultdict(float, {'NOUN': 0.0}),
#              'WORD+TAG_BIGRAM=earnings+NOUN+VERB': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'WORD+NEXT_WORD=earnings': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_WORD_SUFFIX=ted': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.875,
#                           'ADP': 0.625,
#                           'ADV': -0.775,
#                           'CONJ': 0.0,
#                           'DET': -0.1,
#                           'NOUN': 0.225,
#                           'NUM': 0.225,
#                           'PRON': 0.0,
#                           'PRT': -0.85,
#                           'VERB': -0.225}),
#              'SUFFIX=ngs': defaultdict(float, {'NOUN': 0.0, 'VERB': 0.0}),
#              'PREV_TAG+SUFFIX=VERB_ngs': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_WORD+WORD=reported+earnings': defaultdict(float,
#                          {'NOUN': 0.0}),
#              'SUFFIX+2TAGS=ngs+NOUN+VERB': defaultdict(float, {'NOUN': 0.0}),
#              'PREV_TAG+WORD=VERB+earnings': defaultdict(float, {'NOUN': 0.0}),
#              'NEXT_2WORDS=of+$': defaultdict(float,
#                          {'ADJ': -0.225,
#                           'ADP': -0.15,
#                           'NOUN': 0.375,
#                           'NUM': 0.0}),
#              'SUFFIX=are': defaultdict(float,
#                          {'ADJ': -0.45,
#                           'ADP': -0.225,
#                           'ADV': -0.45,
#                           'DET': -0.225,
#                           'NOUN': 0.35,
#                           'PRT': -0.225,
#                           'VERB': 1.225}),
#              'SUFFIX+2TAGS=are+ADV+DET': defaultdict(float,
#                          {'ADV': -0.225, 'NOUN': 0.225}),
#              'PREV_TAG+SUFFIX=DET_are': defaultdict(float,
#                          {'ADJ': -0.225,
#                           'ADV': -0.225,
#                           'NOUN': 0.45,
#                           'VERB': 0.0}),
#              'NEXT_2WORDS=,+for': defaultdict(float,
#                          {'ADP': 0.0,
#                           'ADV': -0.225,
#                           'NOUN': 0.225,
#                           'NUM': 0.0}),
#              'PREV_WORD=a': defaultdict(float,
#                          {'.': 0.4,
#                           'ADJ': 0.475,
#                           'ADP': -0.2,
#                           'ADV': 0.0,
#                           'DET': -0.225,
#                           'NOUN': 0.425,
#                           'NUM': -0.225,
#                           'VERB': -0.65}),
#              'WORD+NEXT_WORD=share': defaultdict(float,
#                          {'ADJ': -0.45,
#                           'ADV': -0.225,
#                           'DET': -0.225,
#                           'NOUN': 0.9,
#                           'VERB': 0.0}),
#              'PREV_WORD+WORD=a+share': defaultdict(float,
#                          {'ADJ': -0.225,
#                           'ADV': -0.225,
#                           'DET': -0.225,
#                           'NOUN': 0.675}),
#              'PREFIX+2TAGS=sha+ADV+DET': defaultdict(float,
#                          {'ADV': -0.225, 'NOUN': 0.225}),
#              'WORD+TAG_BIGRAM=share+ADV+DET': defaultdict(float,
#                          {'ADV': -0.225, 'NOUN': 0.225}),
#              'PREV_TAG+PREFIX=DET_sha': defaultdict(float,
#                          {'ADJ': -0.225, 'ADV': -0.225, 'NOUN': 0.45}),
#              'WORD=share': defaultdict(float,
#                          {'ADJ': -0.45,
#                           'ADV': -0.225,
#                           'DET': -0.225,
#                           'NOUN': 0.9,
#                           'VERB': 0.0}),
#              'PREV_WORD_PREFIX=a': defaultdict(float,
#                          {'.': 0.4,
#                           'ADJ': 0.475,
#                           'ADP': -0.2,
#                           'ADV': 0.0,
#                           'DET': -0.225,
#                           'NOUN': 0.425,
#                           'NUM': -0.225,
#                           'VERB': -0.65}),
#              'PREV_TAG+WORD=DET+share': defaultdict(float,
#                          {'ADJ': -0.225, 'ADV': -0.225, 'NOUN': 0.45}),
#              'PREFIX=sha': defaultdict(float,
#                          {'ADJ': -0.45,
#                           'ADV': -0.225,
#                           'DET': -0.225,
#                           'NOUN': 0.9,
#                           'VERB': 0.0}),
#              'NORM_WORD=share': defaultdict(float,
#                          {'ADJ': -0.45,
#                           'ADV': -0.225,
#                           'DET': -0.225,
#                           'NOUN': 0.9,
#                           'VERB': 0.0}),
#              'PREV_WORD_SUFFIX=a': defaultdict(float,
#                          {'.': 0.4,
#                           'ADJ': 0.475,
#                           'ADP': -0.2,
#                           'ADV': 0.0,
#                           'DET': -0.225,
#                           'NOUN': 0.425,
#                           'NUM': -0.225,
#                           'VERB': -0.65}),
#              'PREV_TAG_BIGRAM=ADV+DET': defaultdict(float,
#                          {'.': 0.0,
#                           'ADJ': 0.9,
#                           'ADP': -0.2,
#                           'ADV': -0.275,
#                           'CONJ': -0.225,
#                           'DET': 0.2,
#                           'NOUN': 0.025,
#                           'NUM': 0.0,
#                           'PRON': -0.2,
#                           'VERB': -0.225}),
#              ...})

# %%
words = sp.instances[3][0]
tags = sp.instances[3][1]
print("WORDS",words)
print("TAGS",tags)

context = [sp.START] + [sp.normalize(word) for word in words] + [sp.END, sp.END]

print("CONTEXT",context)

prediction_features = sp.get_features("said", "__START__", "PRON", context , 2)

print("FEATURES",prediction_features)

scores = sp.get_scores(prediction_features)

print("SCORES",scores)

# predict the current tag
predicted_tag = max(scores, key=scores.get)

print("PREDICTED TAG",predicted_tag)
# Out:
# WORDS ['He', 'said', 'Hydro-Quebec', 'already', 'has', 'some', '``', 'customers', 'in', 'mind', "''", 'for', 'the', 'power', 'that', 'was', 'to', 'be', 'delivered', 'to', 'Maine', '.']
# TAGS ['PRON', 'VERB', 'NOUN', 'ADV', 'VERB', 'DET', '.', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'DET', 'VERB', 'PRT', 'VERB', 'VERB', 'ADP', 'NOUN', '.']
# CONTEXT ['__START__', 'he', 'said', 'hydro-quebec', 'already', 'has', 'some', '``', 'customers', 'in', 'mind', "''", 'for', 'the', 'power', 'that', 'was', 'to', 'be', 'delivered', 'to', 'maine', '.', '__END__', '__END__']
# FEATURES {'PREFIX+2TAGS=sai+__START__+PRON', 'WORD+TAG_BIGRAM=said+__START__+PRON', 'PREV_WORD+WORD=he+said', 'PREV_TAG+PREFIX=PRON_sai', 'BIAS', 'PREV_WORD_PREFIX=he', 'NEXT_WORD_PREFIX=hyd', 'SUFFIX=aid', 'PREV_WORD_SUFFIX=he', 'PREV_TAG_BIGRAM=__START__+PRON', 'WORD+NEXT_WORD=said', 'WORD=said', 'NEXT_WORD_SUFFIX=bec', 'LEN<=3=False', 'SUFFIX+2TAGS=aid+__START__+PRON', 'PREV_TAG+WORD=PRON+said', 'PREV_TAG+SUFFIX=PRON_aid', 'FIRST_LETTER=s', 'PREFIX=sai', 'PREV_WORD=he', 'PREV_TAG=PRON', 'PREV_TAG2=__START__', 'NEXT_2WORDS=hydro-quebec+already', 'NORM_WORD=said', 'NEXT_WORD=hydro-quebec'}
# SCORES defaultdict(<class 'float'>, {'VERB': 5.575, 'NOUN': 0.22499999999999987, 'PRT': -2.974999999999999, 'ADV': 1.35, 'ADJ': 0.8, '.': 0.0, 'PRON': -0.65, 'DET': -1.2, 'ADP': -0.9250000000000002, 'NUM': -1.625, 'CONJ': -0.15, 'X': -0.42500000000000004})
# PREDICTED TAG VERB

# %%
prediction_features
# Out:
# {'BIAS',
#  'FIRST_LETTER=s',
#  'LEN<=3=False',
#  'NEXT_2WORDS=hydro-quebec+already',
#  'NEXT_WORD=hydro-quebec',
#  'NEXT_WORD_PREFIX=hyd',
#  'NEXT_WORD_SUFFIX=bec',
#  'NORM_WORD=said',
#  'PREFIX+2TAGS=sai+__START__+PRON',
#  'PREFIX=sai',
#  'PREV_TAG+PREFIX=PRON_sai',
#  'PREV_TAG+SUFFIX=PRON_aid',
#  'PREV_TAG+WORD=PRON+said',
#  'PREV_TAG2=__START__',
#  'PREV_TAG=PRON',
#  'PREV_TAG_BIGRAM=__START__+PRON',
#  'PREV_WORD+WORD=he+said',
#  'PREV_WORD=he',
#  'PREV_WORD_PREFIX=he',
#  'PREV_WORD_SUFFIX=he',
#  'SUFFIX+2TAGS=aid+__START__+PRON',
#  'SUFFIX=aid',
#  'WORD+NEXT_WORD=said',
#  'WORD+TAG_BIGRAM=said+__START__+PRON',
#  'WORD=said'}

# %%
prediction_features

# %%
prediction = sp.predict(words, method="greedy")
global_gold_features, global_prediction_features = sp.get_global_features(words, prediction, tags)

print(global_gold_features['DET'])
print(global_prediction_features['DET'])
# Out:
# Counter({'BIAS': 3, 'LEN<=3=False': 2, 'FIRST_LETTER=t': 2, 'PREV_TAG+WORD=VERB+some': 1, 'WORD+TAG_BIGRAM=some+ADV+VERB': 1, 'PREV_TAG=VERB': 1, 'PREV_WORD=has': 1, 'PREV_TAG+PREFIX=VERB_som': 1, 'PREV_WORD_SUFFIX=has': 1, 'WORD+NEXT_WORD=some': 1, 'NEXT_2WORDS=``+customers': 1, 'NORM_WORD=some': 1, 'SUFFIX+2TAGS=ome+ADV+VERB': 1, 'PREFIX=som': 1, 'FIRST_LETTER=s': 1, 'NEXT_WORD=``': 1, 'NEXT_WORD_SUFFIX=``': 1, 'PREV_WORD_PREFIX=has': 1, 'PREV_TAG+SUFFIX=VERB_ome': 1, 'PREV_TAG2=ADV': 1, 'NEXT_WORD_PREFIX=``': 1, 'PREFIX+2TAGS=som+ADV+VERB': 1, 'SUFFIX=ome': 1, 'PREV_TAG_BIGRAM=ADV+VERB': 1, 'WORD=some': 1, 'PREV_WORD+WORD=has+some': 1, 'PREV_WORD+WORD=for+the': 1, 'PREV_TAG+SUFFIX=ADP_the': 1, 'SUFFIX=the': 1, 'PREFIX=the': 1, 'PREV_WORD=for': 1, 'NEXT_WORD_SUFFIX=wer': 1, 'PREV_TAG=ADP': 1, 'LEN<=3=True': 1, 'NEXT_2WORDS=power+that': 1, 'PREV_TAG2=.': 1, 'NORM_WORD=the': 1, 'WORD+NEXT_WORD=the': 1, 'WORD=the': 1, 'PREV_TAG_BIGRAM=.+ADP': 1, 'PREV_WORD_PREFIX=for': 1, 'PREFIX+2TAGS=the+.+ADP': 1, 'WORD+TAG_BIGRAM=the+.+ADP': 1, 'NEXT_WORD=power': 1, 'SUFFIX+2TAGS=the+.+ADP': 1, 'NEXT_WORD_PREFIX=pow': 1, 'PREV_TAG+WORD=ADP+the': 1, 'PREV_WORD_SUFFIX=for': 1, 'PREV_TAG+PREFIX=ADP_the': 1, 'PREV_WORD+WORD=power+that': 1, 'NEXT_WORD_SUFFIX=was': 1, 'NEXT_2WORDS=was+to': 1, 'WORD=that': 1, 'NEXT_WORD=was': 1, 'PREFIX=tha': 1, 'WORD+NEXT_WORD=that': 1, 'PREV_TAG+PREFIX=NOUN_tha': 1, 'WORD+TAG_BIGRAM=that+DET+NOUN': 1, 'PREV_WORD=power': 1, 'PREV_WORD_PREFIX=pow': 1, 'PREV_TAG2=DET': 1, 'PREV_TAG=NOUN': 1, 'PREV_TAG_BIGRAM=DET+NOUN': 1, 'PREV_WORD_SUFFIX=wer': 1, 'NEXT_WORD_PREFIX=was': 1, 'SUFFIX+2TAGS=hat+DET+NOUN': 1, 'SUFFIX=hat': 1, 'PREFIX+2TAGS=tha+DET+NOUN': 1, 'PREV_TAG+WORD=NOUN+that': 1, 'NORM_WORD=that': 1, 'PREV_TAG+SUFFIX=NOUN_hat': 1})
# Counter({'BIAS': 3, 'LEN<=3=False': 2, 'FIRST_LETTER=t': 2, 'PREV_TAG+WORD=VERB+some': 1, 'WORD+TAG_BIGRAM=some+ADV+VERB': 1, 'PREV_TAG=VERB': 1, 'PREV_WORD=has': 1, 'PREV_TAG+PREFIX=VERB_som': 1, 'PREV_WORD_SUFFIX=has': 1, 'WORD+NEXT_WORD=some': 1, 'NEXT_2WORDS=``+customers': 1, 'NORM_WORD=some': 1, 'SUFFIX+2TAGS=ome+ADV+VERB': 1, 'PREFIX=som': 1, 'FIRST_LETTER=s': 1, 'NEXT_WORD=``': 1, 'NEXT_WORD_SUFFIX=``': 1, 'PREV_WORD_PREFIX=has': 1, 'PREV_TAG+SUFFIX=VERB_ome': 1, 'PREV_TAG2=ADV': 1, 'NEXT_WORD_PREFIX=``': 1, 'PREFIX+2TAGS=som+ADV+VERB': 1, 'SUFFIX=ome': 1, 'PREV_TAG_BIGRAM=ADV+VERB': 1, 'WORD=some': 1, 'PREV_WORD+WORD=has+some': 1, 'PREV_WORD+WORD=for+the': 1, 'PREV_TAG+SUFFIX=ADP_the': 1, 'SUFFIX=the': 1, 'PREFIX=the': 1, 'PREV_WORD=for': 1, 'NEXT_WORD_SUFFIX=wer': 1, 'PREV_TAG=ADP': 1, 'LEN<=3=True': 1, 'NEXT_2WORDS=power+that': 1, 'PREV_TAG2=.': 1, 'NORM_WORD=the': 1, 'WORD+NEXT_WORD=the': 1, 'WORD=the': 1, 'PREV_TAG_BIGRAM=.+ADP': 1, 'PREV_WORD_PREFIX=for': 1, 'PREFIX+2TAGS=the+.+ADP': 1, 'WORD+TAG_BIGRAM=the+.+ADP': 1, 'NEXT_WORD=power': 1, 'SUFFIX+2TAGS=the+.+ADP': 1, 'NEXT_WORD_PREFIX=pow': 1, 'PREV_TAG+WORD=ADP+the': 1, 'PREV_WORD_SUFFIX=for': 1, 'PREV_TAG+PREFIX=ADP_the': 1, 'PREV_WORD+WORD=power+that': 1, 'NEXT_WORD_SUFFIX=was': 1, 'NEXT_2WORDS=was+to': 1, 'WORD=that': 1, 'NEXT_WORD=was': 1, 'PREFIX=tha': 1, 'WORD+NEXT_WORD=that': 1, 'PREV_TAG+PREFIX=NOUN_tha': 1, 'WORD+TAG_BIGRAM=that+DET+NOUN': 1, 'PREV_WORD=power': 1, 'PREV_WORD_PREFIX=pow': 1, 'PREV_TAG2=DET': 1, 'PREV_TAG=NOUN': 1, 'PREV_TAG_BIGRAM=DET+NOUN': 1, 'PREV_WORD_SUFFIX=wer': 1, 'NEXT_WORD_PREFIX=was': 1, 'SUFFIX+2TAGS=hat+DET+NOUN': 1, 'SUFFIX=hat': 1, 'PREFIX+2TAGS=tha+DET+NOUN': 1, 'PREV_TAG+WORD=NOUN+that': 1, 'NORM_WORD=that': 1, 'PREV_TAG+SUFFIX=NOUN_hat': 1})

# %%
iteration = 1
for tag, fids in global_gold_features.items():
  print(tag, fids)
  for fid, count in fids.items():
    nr_iters_at_this_weight = iteration - sp.timestamps[fid][tag]
        # self.weight_totals[fid][tag] += nr_iters_at_this_weight * self.feature_weights[fid][tag]
        # self.timestamps[fid][tag] = iteration
        # self.feature_weights[fid][tag] += learning_rate * count
# Out:
# PRON Counter({'NORM_WORD=he': 1, 'PREV_TAG+PREFIX=__START___He': 1, 'SUFFIX=He': 1, 'PREV_TAG+WORD=__START__+He': 1, 'FIRST_LETTER=H': 1, 'NEXT_2WORDS=said+hydro-quebec': 1, 'SUFFIX+2TAGS=He+__START__+__START__': 1, 'BIAS': 1, 'PREV_WORD=__START__': 1, 'LEN<=3=True': 1, 'PREV_TAG_BIGRAM=__START__+__START__': 1, 'PREFIX=He': 1, 'PREV_TAG+SUFFIX=__START___He': 1, 'PREV_WORD_PREFIX=__S': 1, 'PREV_WORD+WORD=__START__+he': 1, 'WORD+TAG_BIGRAM=He+__START__+__START__': 1, 'WORD=He': 1, 'PREV_TAG=__START__': 1, 'PREV_WORD_SUFFIX=T__': 1, 'NEXT_WORD=said': 1, 'NEXT_WORD_SUFFIX=aid': 1, 'PREV_TAG2=__START__': 1, 'NEXT_WORD_PREFIX=sai': 1, 'PREFIX+2TAGS=He+__START__+__START__': 1, 'WORD+NEXT_WORD=He': 1})
# VERB Counter({'BIAS': 5, 'LEN<=3=True': 3, 'LEN<=3=False': 2, 'PREV_TAG2=NOUN': 2, 'NEXT_WORD_PREFIX=to': 2, 'NEXT_WORD_SUFFIX=to': 2, 'NEXT_WORD=to': 2, 'PREFIX+2TAGS=sai+__START__+PRON': 1, 'WORD+TAG_BIGRAM=said+__START__+PRON': 1, 'PREV_WORD+WORD=he+said': 1, 'PREV_TAG+PREFIX=PRON_sai': 1, 'PREV_WORD_PREFIX=he': 1, 'NEXT_WORD_PREFIX=hyd': 1, 'SUFFIX=aid': 1, 'PREV_WORD_SUFFIX=he': 1, 'PREV_TAG_BIGRAM=__START__+PRON': 1, 'WORD+NEXT_WORD=said': 1, 'WORD=said': 1, 'NEXT_WORD_SUFFIX=bec': 1, 'SUFFIX+2TAGS=aid+__START__+PRON': 1, 'PREV_TAG+WORD=PRON+said': 1, 'PREV_TAG+SUFFIX=PRON_aid': 1, 'FIRST_LETTER=s': 1, 'PREFIX=sai': 1, 'PREV_WORD=he': 1, 'PREV_TAG=PRON': 1, 'PREV_TAG2=__START__': 1, 'NEXT_2WORDS=hydro-quebec+already': 1, 'NORM_WORD=said': 1, 'NEXT_WORD=hydro-quebec': 1, 'PREV_WORD_SUFFIX=ady': 1, 'SUFFIX+2TAGS=has+NOUN+ADV': 1, 'PREFIX=has': 1, 'NEXT_WORD_PREFIX=som': 1, 'PREV_TAG+SUFFIX=ADV_has': 1, 'NORM_WORD=has': 1, 'PREV_WORD+WORD=already+has': 1, 'NEXT_WORD=some': 1, 'PREV_TAG_BIGRAM=NOUN+ADV': 1, 'PREV_TAG=ADV': 1, 'WORD=has': 1, 'PREV_TAG+WORD=ADV+has': 1, 'NEXT_WORD_SUFFIX=ome': 1, 'PREV_WORD=already': 1, 'PREV_TAG+PREFIX=ADV_has': 1, 'NEXT_2WORDS=some+``': 1, 'PREV_WORD_PREFIX=alr': 1, 'PREFIX+2TAGS=has+NOUN+ADV': 1, 'FIRST_LETTER=h': 1, 'WORD+TAG_BIGRAM=has+NOUN+ADV': 1, 'SUFFIX=has': 1, 'WORD+NEXT_WORD=has': 1, 'WORD+TAG_BIGRAM=was+NOUN+DET': 1, 'WORD=was': 1, 'WORD+NEXT_WORD=was': 1, 'SUFFIX=was': 1, 'PREFIX+2TAGS=was+NOUN+DET': 1, 'FIRST_LETTER=w': 1, 'PREV_TAG_BIGRAM=NOUN+DET': 1, 'PREV_TAG+PREFIX=DET_was': 1, 'NEXT_2WORDS=to+be': 1, 'PREFIX=was': 1, 'PREV_WORD+WORD=that+was': 1, 'PREV_TAG+WORD=DET+was': 1, 'PREV_WORD_PREFIX=tha': 1, 'SUFFIX+2TAGS=was+NOUN+DET': 1, 'NORM_WORD=was': 1, 'PREV_TAG+SUFFIX=DET_was': 1, 'PREV_WORD_SUFFIX=hat': 1, 'PREV_WORD=that': 1, 'PREV_TAG=DET': 1, 'PREV_WORD=to': 1, 'PREV_TAG=PRT': 1, 'FIRST_LETTER=b': 1, 'WORD=be': 1, 'NEXT_WORD_PREFIX=del': 1, 'NEXT_WORD_SUFFIX=red': 1, 'NEXT_2WORDS=delivered+to': 1, 'NORM_WORD=be': 1, 'WORD+TAG_BIGRAM=be+VERB+PRT': 1, 'PREV_WORD+WORD=to+be': 1, 'SUFFIX+2TAGS=be+VERB+PRT': 1, 'PREV_WORD_SUFFIX=to': 1, 'PREFIX=be': 1, 'PREV_TAG_BIGRAM=VERB+PRT': 1, 'PREV_TAG+SUFFIX=PRT_be': 1, 'SUFFIX=be': 1, 'WORD+NEXT_WORD=be': 1, 'PREV_WORD_PREFIX=to': 1, 'PREV_TAG+PREFIX=PRT_be': 1, 'NEXT_WORD=delivered': 1, 'PREFIX+2TAGS=be+VERB+PRT': 1, 'PREV_TAG+WORD=PRT+be': 1, 'PREV_TAG2=VERB': 1, 'NORM_WORD=delivered': 1, 'PREV_TAG=VERB': 1, 'PREV_TAG+SUFFIX=VERB_red': 1, 'PREV_WORD_PREFIX=be': 1, 'PREV_TAG2=PRT': 1, 'FIRST_LETTER=d': 1, 'PREFIX=del': 1, 'WORD+TAG_BIGRAM=delivered+PRT+VERB': 1, 'PREV_WORD=be': 1, 'NEXT_2WORDS=to+maine': 1, 'PREV_TAG_BIGRAM=PRT+VERB': 1, 'SUFFIX+2TAGS=red+PRT+VERB': 1, 'PREV_TAG+PREFIX=VERB_del': 1, 'PREV_TAG+WORD=VERB+delivered': 1, 'WORD+NEXT_WORD=delivered': 1, 'WORD=delivered': 1, 'PREV_WORD_SUFFIX=be': 1, 'PREV_WORD+WORD=be+delivered': 1, 'SUFFIX=red': 1, 'PREFIX+2TAGS=del+PRT+VERB': 1})
# NOUN Counter({'BIAS': 5, 'LEN<=3=False': 5, 'PREV_TAG=ADP': 2, 'SUFFIX=bec': 1, 'PREV_TAG=VERB': 1, 'FIRST_LETTER=H': 1, 'WORD=Hydro-Quebec': 1, 'PREFIX+2TAGS=Hyd+PRON+VERB': 1, 'PREV_TAG+PREFIX=VERB_Hyd': 1, 'NORM_WORD=hydro-quebec': 1, 'NEXT_2WORDS=already+has': 1, 'PREV_TAG_BIGRAM=PRON+VERB': 1, 'PREV_TAG2=PRON': 1, 'PREV_WORD+WORD=said+hydro-quebec': 1, 'PREV_WORD=said': 1, 'NEXT_WORD=already': 1, 'WORD+TAG_BIGRAM=Hydro-Quebec+PRON+VERB': 1, 'NEXT_WORD_PREFIX=alr': 1, 'PREV_TAG+SUFFIX=VERB_bec': 1, 'NEXT_WORD_SUFFIX=ady': 1, 'PREV_TAG+WORD=VERB+Hydro-Quebec': 1, 'PREV_WORD_SUFFIX=aid': 1, 'PREFIX=Hyd': 1, 'WORD+NEXT_WORD=Hydro-Quebec': 1, 'SUFFIX+2TAGS=bec+PRON+VERB': 1, 'PREV_WORD_PREFIX=sai': 1, 'PREV_TAG+PREFIX=._cus': 1, 'PREV_WORD=``': 1, 'WORD+TAG_BIGRAM=customers+DET+.': 1, 'WORD+NEXT_WORD=customers': 1, 'NEXT_WORD_PREFIX=in': 1, 'SUFFIX+2TAGS=ers+DET+.': 1, 'SUFFIX=ers': 1, 'NEXT_WORD_SUFFIX=in': 1, 'PREV_WORD_PREFIX=``': 1, 'PREV_TAG2=DET': 1, 'NORM_WORD=customers': 1, 'PREV_WORD+WORD=``+customers': 1, 'FIRST_LETTER=c': 1, 'PREV_TAG+SUFFIX=._ers': 1, 'PREV_TAG_BIGRAM=DET+.': 1, 'NEXT_WORD=in': 1, 'PREFIX=cus': 1, 'PREV_WORD_SUFFIX=``': 1, 'PREV_TAG=.': 1, 'PREV_TAG+WORD=.+customers': 1, 'NEXT_2WORDS=in+mind': 1, 'PREFIX+2TAGS=cus+DET+.': 1, 'WORD=customers': 1, 'WORD=mind': 1, 'PREFIX+2TAGS=min+NOUN+ADP': 1, 'NORM_WORD=mind': 1, 'PREV_TAG+SUFFIX=ADP_ind': 1, 'PREV_WORD_SUFFIX=in': 1, 'WORD+TAG_BIGRAM=mind+NOUN+ADP': 1, 'FIRST_LETTER=m': 1, 'PREV_TAG+WORD=ADP+mind': 1, "NEXT_2WORDS=''+for": 1, "NEXT_WORD_PREFIX=''": 1, "NEXT_WORD_SUFFIX=''": 1, 'PREV_WORD=in': 1, 'WORD+NEXT_WORD=mind': 1, 'PREV_WORD+WORD=in+mind': 1, "NEXT_WORD=''": 1, 'SUFFIX+2TAGS=ind+NOUN+ADP': 1, 'PREFIX=min': 1, 'PREV_WORD_PREFIX=in': 1, 'PREV_TAG_BIGRAM=NOUN+ADP': 1, 'SUFFIX=ind': 1, 'PREV_TAG+PREFIX=ADP_min': 1, 'PREV_TAG2=NOUN': 1, 'PREV_TAG_BIGRAM=ADP+DET': 1, 'WORD=power': 1, 'NEXT_WORD_SUFFIX=hat': 1, 'PREV_TAG+PREFIX=DET_pow': 1, 'PREV_TAG2=ADP': 1, 'PREV_WORD_PREFIX=the': 1, 'NEXT_WORD_PREFIX=tha': 1, 'PREV_TAG+WORD=DET+power': 1, 'WORD+TAG_BIGRAM=power+ADP+DET': 1, 'PREFIX+2TAGS=pow+ADP+DET': 1, 'FIRST_LETTER=p': 1, 'PREV_WORD_SUFFIX=the': 1, 'NEXT_WORD=that': 1, 'NEXT_2WORDS=that+was': 1, 'NORM_WORD=power': 1, 'WORD+NEXT_WORD=power': 1, 'PREV_TAG+SUFFIX=DET_wer': 1, 'SUFFIX+2TAGS=wer+ADP+DET': 1, 'SUFFIX=wer': 1, 'PREFIX=pow': 1, 'PREV_WORD+WORD=the+power': 1, 'PREV_WORD=the': 1, 'PREV_TAG=DET': 1, 'PREV_WORD+WORD=to+maine': 1, 'PREV_WORD=to': 1, 'NEXT_2WORDS=.+__END__': 1, 'WORD=Maine': 1, 'NEXT_WORD=.': 1, 'PREV_TAG+WORD=ADP+Maine': 1, 'PREV_TAG+SUFFIX=ADP_ine': 1, 'NEXT_WORD_SUFFIX=.': 1, 'PREFIX+2TAGS=Mai+VERB+ADP': 1, 'FIRST_LETTER=M': 1, 'NORM_WORD=maine': 1, 'PREV_TAG_BIGRAM=VERB+ADP': 1, 'PREV_WORD_SUFFIX=to': 1, 'SUFFIX+2TAGS=ine+VERB+ADP': 1, 'WORD+TAG_BIGRAM=Maine+VERB+ADP': 1, 'PREFIX=Mai': 1, 'NEXT_WORD_PREFIX=.': 1, 'PREV_TAG+PREFIX=ADP_Mai': 1, 'SUFFIX=ine': 1, 'PREV_WORD_PREFIX=to': 1, 'PREV_TAG2=VERB': 1, 'WORD+NEXT_WORD=Maine': 1})
# ADV Counter({'PREV_WORD=hydro-quebec': 1, 'PREV_WORD_SUFFIX=bec': 1, 'PREV_TAG+WORD=NOUN+already': 1, 'WORD+NEXT_WORD=already': 1, 'PREFIX=alr': 1, 'PREV_TAG+PREFIX=NOUN_alr': 1, 'BIAS': 1, 'PREV_WORD_PREFIX=hyd': 1, 'LEN<=3=False': 1, 'NEXT_WORD_PREFIX=has': 1, 'PREV_TAG=NOUN': 1, 'NEXT_WORD_SUFFIX=has': 1, 'PREV_TAG+SUFFIX=NOUN_ady': 1, 'SUFFIX=ady': 1, 'WORD+TAG_BIGRAM=already+VERB+NOUN': 1, 'FIRST_LETTER=a': 1, 'NORM_WORD=already': 1, 'NEXT_WORD=has': 1, 'PREFIX+2TAGS=alr+VERB+NOUN': 1, 'NEXT_2WORDS=has+some': 1, 'PREV_WORD+WORD=hydro-quebec+already': 1, 'SUFFIX+2TAGS=ady+VERB+NOUN': 1, 'WORD=already': 1, 'PREV_TAG2=VERB': 1, 'PREV_TAG_BIGRAM=VERB+NOUN': 1})
# DET Counter({'BIAS': 3, 'LEN<=3=False': 2, 'FIRST_LETTER=t': 2, 'PREV_TAG+WORD=VERB+some': 1, 'WORD+TAG_BIGRAM=some+ADV+VERB': 1, 'PREV_TAG=VERB': 1, 'PREV_WORD=has': 1, 'PREV_TAG+PREFIX=VERB_som': 1, 'PREV_WORD_SUFFIX=has': 1, 'WORD+NEXT_WORD=some': 1, 'NEXT_2WORDS=``+customers': 1, 'NORM_WORD=some': 1, 'SUFFIX+2TAGS=ome+ADV+VERB': 1, 'PREFIX=som': 1, 'FIRST_LETTER=s': 1, 'NEXT_WORD=``': 1, 'NEXT_WORD_SUFFIX=``': 1, 'PREV_WORD_PREFIX=has': 1, 'PREV_TAG+SUFFIX=VERB_ome': 1, 'PREV_TAG2=ADV': 1, 'NEXT_WORD_PREFIX=``': 1, 'PREFIX+2TAGS=som+ADV+VERB': 1, 'SUFFIX=ome': 1, 'PREV_TAG_BIGRAM=ADV+VERB': 1, 'WORD=some': 1, 'PREV_WORD+WORD=has+some': 1, 'PREV_WORD+WORD=for+the': 1, 'PREV_TAG+SUFFIX=ADP_the': 1, 'SUFFIX=the': 1, 'PREFIX=the': 1, 'PREV_WORD=for': 1, 'NEXT_WORD_SUFFIX=wer': 1, 'PREV_TAG=ADP': 1, 'LEN<=3=True': 1, 'NEXT_2WORDS=power+that': 1, 'PREV_TAG2=.': 1, 'NORM_WORD=the': 1, 'WORD+NEXT_WORD=the': 1, 'WORD=the': 1, 'PREV_TAG_BIGRAM=.+ADP': 1, 'PREV_WORD_PREFIX=for': 1, 'PREFIX+2TAGS=the+.+ADP': 1, 'WORD+TAG_BIGRAM=the+.+ADP': 1, 'NEXT_WORD=power': 1, 'SUFFIX+2TAGS=the+.+ADP': 1, 'NEXT_WORD_PREFIX=pow': 1, 'PREV_TAG+WORD=ADP+the': 1, 'PREV_WORD_SUFFIX=for': 1, 'PREV_TAG+PREFIX=ADP_the': 1, 'PREV_WORD+WORD=power+that': 1, 'NEXT_WORD_SUFFIX=was': 1, 'NEXT_2WORDS=was+to': 1, 'WORD=that': 1, 'NEXT_WORD=was': 1, 'PREFIX=tha': 1, 'WORD+NEXT_WORD=that': 1, 'PREV_TAG+PREFIX=NOUN_tha': 1, 'WORD+TAG_BIGRAM=that+DET+NOUN': 1, 'PREV_WORD=power': 1, 'PREV_WORD_PREFIX=pow': 1, 'PREV_TAG2=DET': 1, 'PREV_TAG=NOUN': 1, 'PREV_TAG_BIGRAM=DET+NOUN': 1, 'PREV_WORD_SUFFIX=wer': 1, 'NEXT_WORD_PREFIX=was': 1, 'SUFFIX+2TAGS=hat+DET+NOUN': 1, 'SUFFIX=hat': 1, 'PREFIX+2TAGS=tha+DET+NOUN': 1, 'PREV_TAG+WORD=NOUN+that': 1, 'NORM_WORD=that': 1, 'PREV_TAG+SUFFIX=NOUN_hat': 1})
# . Counter({'BIAS': 3, 'LEN<=3=True': 3, 'PREV_TAG2=ADP': 2, 'PREV_TAG=NOUN': 2, 'PREV_TAG_BIGRAM=ADP+NOUN': 2, 'NORM_WORD=``': 1, 'PREV_WORD+WORD=some+``': 1, 'WORD=``': 1, 'NEXT_WORD=customers': 1, 'SUFFIX=``': 1, 'PREV_WORD=some': 1, 'WORD+NEXT_WORD=``': 1, 'PREV_TAG+SUFFIX=DET_``': 1, 'NEXT_WORD_PREFIX=cus': 1, 'PREV_TAG+WORD=DET+``': 1, 'PREV_TAG+PREFIX=DET_``': 1, 'PREFIX+2TAGS=``+VERB+DET': 1, 'FIRST_LETTER=`': 1, 'SUFFIX+2TAGS=``+VERB+DET': 1, 'NEXT_WORD_SUFFIX=ers': 1, 'NEXT_2WORDS=customers+in': 1, 'PREFIX=``': 1, 'PREV_WORD_PREFIX=som': 1, 'PREV_WORD_SUFFIX=ome': 1, 'WORD+TAG_BIGRAM=``+VERB+DET': 1, 'PREV_TAG_BIGRAM=VERB+DET': 1, 'PREV_TAG2=VERB': 1, 'PREV_TAG=DET': 1, "PREV_TAG+SUFFIX=NOUN_''": 1, "WORD+NEXT_WORD=''": 1, "SUFFIX=''": 1, 'NEXT_WORD_SUFFIX=for': 1, "NORM_WORD=''": 1, "SUFFIX+2TAGS=''+ADP+NOUN": 1, "WORD=''": 1, "FIRST_LETTER='": 1, "PREFIX=''": 1, 'NEXT_2WORDS=for+the': 1, "PREV_TAG+PREFIX=NOUN_''": 1, "PREV_WORD+WORD=mind+''": 1, "PREV_TAG+WORD=NOUN+''": 1, 'PREV_WORD=mind': 1, 'NEXT_WORD=for': 1, 'NEXT_WORD_PREFIX=for': 1, "PREFIX+2TAGS=''+ADP+NOUN": 1, 'PREV_WORD_SUFFIX=ind': 1, 'PREV_WORD_PREFIX=min': 1, "WORD+TAG_BIGRAM=''+ADP+NOUN": 1, 'SUFFIX=.': 1, 'PREV_TAG+WORD=NOUN+.': 1, 'PREV_TAG+PREFIX=NOUN_.': 1, 'WORD=.': 1, 'PREV_WORD=maine': 1, 'PREFIX=.': 1, 'SUFFIX+2TAGS=.+ADP+NOUN': 1, 'FIRST_LETTER=.': 1, 'NORM_WORD=.': 1, 'PREFIX+2TAGS=.+ADP+NOUN': 1, 'PREV_WORD_SUFFIX=ine': 1, 'PREV_WORD+WORD=maine+.': 1, 'PREV_WORD_PREFIX=mai': 1, 'NEXT_WORD_SUFFIX=D__': 1, 'NEXT_WORD=__END__': 1, 'NEXT_WORD_PREFIX=__E': 1, 'WORD+NEXT_WORD=.': 1, 'WORD+TAG_BIGRAM=.+ADP+NOUN': 1, 'PREV_TAG+SUFFIX=NOUN_.': 1, 'NEXT_2WORDS=__END__+__END__': 1})
# ADP Counter({'BIAS': 3, 'LEN<=3=True': 3, 'SUFFIX=in': 1, 'WORD=in': 1, 'NEXT_WORD_SUFFIX=ind': 1, 'NEXT_WORD_PREFIX=min': 1, 'FIRST_LETTER=i': 1, 'PREV_TAG2=.': 1, 'PREV_TAG+PREFIX=NOUN_in': 1, 'NORM_WORD=in': 1, 'PREV_TAG_BIGRAM=.+NOUN': 1, 'PREV_TAG=NOUN': 1, 'WORD+NEXT_WORD=in': 1, 'SUFFIX+2TAGS=in+.+NOUN': 1, 'PREV_TAG+WORD=NOUN+in': 1, 'PREFIX=in': 1, 'PREV_TAG+SUFFIX=NOUN_in': 1, 'PREFIX+2TAGS=in+.+NOUN': 1, 'PREV_WORD=customers': 1, 'PREV_WORD_PREFIX=cus': 1, 'PREV_WORD_SUFFIX=ers': 1, 'NEXT_WORD=mind': 1, 'WORD+TAG_BIGRAM=in+.+NOUN': 1, "NEXT_2WORDS=mind+''": 1, 'PREV_WORD+WORD=customers+in': 1, "PREV_WORD_SUFFIX=''": 1, 'PREFIX=for': 1, 'PREV_TAG+PREFIX=._for': 1, 'SUFFIX=for': 1, 'PREV_TAG+SUFFIX=._for': 1, 'SUFFIX+2TAGS=for+NOUN+.': 1, 'PREV_TAG_BIGRAM=NOUN+.': 1, 'PREV_TAG+WORD=.+for': 1, 'NORM_WORD=for': 1, "PREV_WORD+WORD=''+for": 1, 'PREFIX+2TAGS=for+NOUN+.': 1, 'NEXT_2WORDS=the+power': 1, 'NEXT_WORD_PREFIX=the': 1, 'NEXT_WORD=the': 1, "PREV_WORD_PREFIX=''": 1, 'WORD+TAG_BIGRAM=for+NOUN+.': 1, 'NEXT_WORD_SUFFIX=the': 1, 'PREV_TAG=.': 1, "PREV_WORD=''": 1, 'WORD=for': 1, 'FIRST_LETTER=f': 1, 'PREV_TAG2=NOUN': 1, 'WORD+NEXT_WORD=for': 1, 'PREV_TAG=VERB': 1, 'PREV_WORD_SUFFIX=red': 1, 'PREFIX+2TAGS=to+VERB+VERB': 1, 'NEXT_WORD_SUFFIX=ine': 1, 'WORD+NEXT_WORD=to': 1, 'NEXT_WORD_PREFIX=mai': 1, 'SUFFIX+2TAGS=to+VERB+VERB': 1, 'NEXT_2WORDS=maine+.': 1, 'FIRST_LETTER=t': 1, 'SUFFIX=to': 1, 'PREFIX=to': 1, 'PREV_WORD+WORD=delivered+to': 1, 'PREV_WORD_PREFIX=del': 1, 'WORD+TAG_BIGRAM=to+VERB+VERB': 1, 'WORD=to': 1, 'PREV_TAG+PREFIX=VERB_to': 1, 'PREV_TAG+WORD=VERB+to': 1, 'NORM_WORD=to': 1, 'PREV_TAG+SUFFIX=VERB_to': 1, 'PREV_WORD=delivered': 1, 'NEXT_WORD=maine': 1, 'PREV_TAG_BIGRAM=VERB+VERB': 1, 'PREV_TAG2=VERB': 1})
# PRT Counter({'PREV_TAG=VERB': 1, 'PREV_WORD=was': 1, 'WORD+TAG_BIGRAM=to+DET+VERB': 1, 'BIAS': 1, 'LEN<=3=True': 1, 'PREV_WORD+WORD=was+to': 1, 'PREV_TAG_BIGRAM=DET+VERB': 1, 'WORD+NEXT_WORD=to': 1, 'PREV_WORD_SUFFIX=was': 1, 'NEXT_2WORDS=be+delivered': 1, 'NEXT_WORD=be': 1, 'SUFFIX+2TAGS=to+DET+VERB': 1, 'NEXT_WORD_SUFFIX=be': 1, 'PREV_TAG2=DET': 1, 'FIRST_LETTER=t': 1, 'SUFFIX=to': 1, 'PREFIX=to': 1, 'WORD=to': 1, 'PREFIX+2TAGS=to+DET+VERB': 1, 'PREV_TAG+PREFIX=VERB_to': 1, 'PREV_TAG+WORD=VERB+to': 1, 'NORM_WORD=to': 1, 'NEXT_WORD_PREFIX=be': 1, 'PREV_TAG+SUFFIX=VERB_to': 1, 'PREV_WORD_PREFIX=was': 1})

# %%
list(zip(prediction,tags))
# Out:
# [('PRON', 'PRON'),
#  ('VERB', 'VERB'),
#  ('NOUN', 'NOUN'),
#  ('ADV', 'ADV'),
#  ('VERB', 'VERB'),
#  ('DET', 'DET'),
#  ('.', '.'),
#  ('NOUN', 'NOUN'),
#  ('ADP', 'ADP'),
#  ('NOUN', 'NOUN'),
#  ('.', '.'),
#  ('ADP', 'ADP'),
#  ('DET', 'DET'),
#  ('NOUN', 'NOUN'),
#  ('DET', 'DET'),
#  ('VERB', 'VERB'),
#  ('PRT', 'PRT'),
#  ('VERB', 'VERB'),
#  ('VERB', 'VERB'),
#  ('ADP', 'ADP'),
#  ('NOUN', 'NOUN'),
#  ('.', '.')]

# %% [markdown]
# # VITERBI

# %%
sp2 = StructuredPerceptron()
inference_method = 'viterbi'
# %time sp2.fit('tiny_POS_train.data', dev_file='tiny_POS_test.data', iterations=5, inference=inference_method)

sp2.save('model_viterbi.pickle')
# Out:
# .................................................1000
# .................................................2000
# 	127176 features
# 	Training accuracy: 0.04
#
# 	Development accuracy: 0.04
#
# .................................................1000
# .................................................2000
# 	127176 features
# 	Training accuracy: 0.04
#
# 	Development accuracy: 0.04
#
# .................................................1000
# .................................................2000
# 	127176 features
# 	Training accuracy: 0.04
#
# 	Development accuracy: 0.04
#
# .................................................1000
# .................................................2000
# 	127176 features
# 	Training accuracy: 0.04
#
# 	Development accuracy: 0.04
#
# .................................................1000
# .................................................2000
# 	127176 features
# 	Training accuracy: 0.04
#
# 	Development accuracy: 0.04
# CPU times: user 1min 14s, sys: 491 ms, total: 1min 14s
# Wall time: 1min 15s
# saving model... done

# %% [markdown]
# ## Debug

# %%
# sp2
allowed_initial_tags = sp2.tag_dict[context[1]]
print(context)
print(context[1])
allowed_initial_tags
# Out:
# ['__START__', 'he', 'said', 'hydro-quebec', 'already', 'has', 'some', '``', 'customers', 'in', 'mind', "''", 'for', 'the', 'power', 'that', 'was', 'to', 'be', 'delivered', 'to', 'maine', '.', '__END__', '__END__']
# he
# {'PRON'}

# %%
N = len(words)
M = len(sp2.tags) #number of tags
tags = sorted(sp2.tags)

print('TAGS',tags)

# create trellis of size M (number of tags) x N (sentence length)
Q = np.ones((M, N)) * float('-Inf')

for j in range(M):
  if not allowed_initial_tags or tags[j] in allowed_initial_tags:
      Q[j,0] = scores[tags[j]]

Q
# Out:
# TAGS ['.', 'ADJ', 'ADP', 'ADV', 'CONJ', 'DET', 'NOUN', 'NUM', 'PRON', 'PRT', 'VERB', 'X']
# array([[ -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf],
#        [ -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf],
#        [ -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf],
#        [ -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf],
#        [ -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf],
#        [ -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf],
#        [ -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf],
#        [ -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf],
#        [-0.65,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf],
#        [ -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf],
#        [ -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf],
#        [ -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,  -inf,
#          -inf,  -inf,  -inf,  -inf]])

# %% [markdown]
# # Prediction

# %%
# In order to load old models, use this:
# sp = StructuredPerceptron()
# sp.load('model_greedy.pickle')
# sp2 = StructuredPerceptron()
# sp2.load('model_viterbi.pickle')

print(sp.predict('Their management plan reforms worked'.split(), method='greedy'))
print(sp2.predict('Their management plan reforms worked'.split(), method='viterbi'))

print(sp.predict("Attack was their best option".split(), method='greedy'))
print(sp2.predict("Attack was their best option".split(), method='viterbi'))


print(sp.predict("This can can fly away".split(), method='greedy'))
print(sp.predict("This can can fly away".split(), method='viterbi'))
# Out:
# ['PRON', 'NOUN', 'NOUN', 'VERB', 'VERB']
# ['X', 'X', 'X', 'X', '.']
# ['NOUN', 'VERB', 'PRON', 'ADJ', 'NOUN']
# ['X', 'X', 'X', 'X', '.']
# ['DET', 'VERB', 'VERB', 'VERB', 'ADV']
# ['X', 'X', 'X', 'X', '.']

# %% [markdown]
# ## Exercise
# Train one structured perceptron with greedy inference and one with Viterbi inference.
# Compare training time and training accuracy.
#
# Load the file `en-ud-dev.conll`. Tag it with both the Structured Perceptrons, compute the respective accuracy, and compare them.

# %%
# your code here

# %% [markdown]
# ## Exercise
# Come up with more features, train a new model, and see whether you improved performance on the development set.

# %%
# your code here
